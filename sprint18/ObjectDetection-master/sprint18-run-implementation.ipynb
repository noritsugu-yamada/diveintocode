# %% [markdown]
# ### Faster-RCNN

# %% [markdown]
# ### 【問題1】学習と推定

# %% [markdown]
# 学習

# %%
# %run train.py -p annotation.txt --n_epochs 20 --n_iter 300
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class (19 classes) :
# {'abraham_grampa_simpson': 687,
#  'apu_nahasapeemapetilon': 206,
#  'bart_simpson': 650,
#  'bg': 0,
#  'charles_montgomery_burns': 650,
#  'chief_wiggum': 209,
#  'comic_book_guy': 208,
#  'edna_krabappel': 212,
#  'homer_simpson': 718,
#  'kent_brockman': 213,
#  'krusty_the_clown': 429,
#  'lisa_simpson': 756,
#  'marge_simpson': 629,
#  'milhouse_van_houten': 210,
#  'moe_szyslak': 403,
#  'ned_flanders': 675,
#  'nelson_muntz': 219,
#  'principal_skinner': 614,
#  'sideshow_bob': 201}
# -------------------------------
# path to config file : ./save\train_20190313-122253_config.pickle
# -------------------------------
# Epoch 1/20
#  92/300 [========>.....................] - ETA: 2:23 - rpn_cls: 3.9148 - rpn_regr: 0.2612 - detector_cls: 4.7316 - detector_regr: 6.3721Exception: 'NoneType' object is not subscriptable
# 123/300 [===========>..................] - ETA: 1:49 - rpn_cls: 3.6030 - rpn_regr: 0.2417 - detector_cls: 4.3069 - detector_regr: 5.4357Exception: 'NoneType' object is not subscriptable
# 223/300 [=====================>........] - ETA: 38s - rpn_cls: 3.0199 - rpn_regr: 0.2038 - detector_cls: 3.5742 - detector_regr: 3.8328Exception: 'NoneType' object is not subscriptable
# 290/300 [============================>.] - ETA: 4s - rpn_cls: 2.8399 - rpn_regr: 0.1906 - detector_cls: 3.3259 - detector_regr: 3.2707Exception: 'NoneType' object is not subscriptable
# 300/300 [==============================] - 137s 456ms/step - rpn_cls: 2.8219 - rpn_regr: 0.1890 - detector_cls: 3.2966 - detector_regr: 3.2045
# Average number of overlapping bounding boxes from RPN = 19.58 for 300 previous iterations
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.551495016611295
# Classifier accuracy for bounding boxes from RPN: 0.53
# Loss RPN classifier: 2.3030298406624077
# Loss RPN regression: 0.14269261407045028
# Loss Detector classifier: 2.437235293587825
# Loss Detector regression: 1.2729103523989518
# Elapsed time: 137.14344835281372[s]
# Total loss decreased from inf to 6.155868100719635, saving weights
# Epoch 2/20
#  92/300 [========>.....................] - ETA: 1:13 - rpn_cls: 2.5520 - rpn_regr: 0.1327 - detector_cls: 2.1221 - detector_regr: 0.4510Exception: 'NoneType' object is not subscriptable
# 299/300 [============================>.] - ETA: 0s - rpn_cls: 2.4182 - rpn_regr: 0.1154 - detector_cls: 2.0680 - detector_regr: 0.4504Average number of overlapping bounding boxes from RPN = 20.416666666666668 for 300 previous iterations
# 300/300 [==============================] - 105s 350ms/step - rpn_cls: 2.4173 - rpn_regr: 0.1154 - detector_cls: 2.0678 - detector_regr: 0.4505
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.431893687707642
# Classifier accuracy for bounding boxes from RPN: 0.545
# Loss RPN classifier: 2.1653918761785294
# Loss RPN regression: 0.10650684233444432
# Loss Detector classifier: 2.0328355320294698
# Loss Detector regression: 0.45843576796352864
# Elapsed time: 116.62089252471924[s]
# Total loss decreased from 6.155868100719635 to 4.763170018505972, saving weights
# Epoch 3/20
# 190/300 [==================>...........] - ETA: 34s - rpn_cls: 1.7212 - rpn_regr: 0.1173 - detector_cls: 2.0863 - detector_regr: 0.4220Exception: 'NoneType' object is not subscriptable
# 298/300 [============================>.] - ETA: 0s - rpn_cls: 1.8504 - rpn_regr: 0.1186 - detector_cls: 2.0594 - detector_regr: 0.4233Average number of overlapping bounding boxes from RPN = 21.046666666666667 for 300 previous iterations
# 300/300 [==============================] - 96s 320ms/step - rpn_cls: 1.8520 - rpn_regr: 0.1186 - detector_cls: 2.0590 - detector_regr: 0.4233
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.079734219269103
# Classifier accuracy for bounding boxes from RPN: 0.5275
# Loss RPN classifier: 2.087787145678629
# Loss RPN regression: 0.118459417669413
# Loss Detector classifier: 2.0042665978272756
# Loss Detector regression: 0.431903547073404
# Elapsed time: 96.62998056411743[s]
# Total loss decreased from 4.763170018505972 to 4.642416708248721, saving weights
# Epoch 4/20
#  50/300 [====>.........................] - ETA: 1:24 - rpn_cls: 2.5910 - rpn_regr: 0.1176 - detector_cls: 2.0845 - detector_regr: 0.5231Exception: 'NoneType' object is not subscriptable
# 158/300 [==============>...............] - ETA: 44s - rpn_cls: 2.6798 - rpn_regr: 0.1364 - detector_cls: 2.0156 - detector_regr: 0.4654Exception: 'NoneType' object is not subscriptable
# 297/300 [============================>.] - ETA: 0s - rpn_cls: 2.4667 - rpn_regr: 0.1364 - detector_cls: 2.0082 - detector_regr: 0.4560Average number of overlapping bounding boxes from RPN = 17.836666666666666 for 300 previous iterations
# 300/300 [==============================] - 98s 326ms/step - rpn_cls: 2.4622 - rpn_regr: 0.1363 - detector_cls: 2.0082 - detector_regr: 0.4559
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.84717607973422
# Classifier accuracy for bounding boxes from RPN: 0.5358333333333334
# Loss RPN classifier: 2.0230575486775257
# Loss RPN regression: 0.13521597729995846
# Loss Detector classifier: 2.006047473549843
# Loss Detector regression: 0.44038578122854233
# Elapsed time: 98.59298944473267[s]
# Total loss decreased from 4.642416708248721 to 4.604706780755869, saving weights
# Epoch 5/20
# 296/300 [============================>.] - ETA: 1s - rpn_cls: 1.4180 - rpn_regr: 0.1389 - detector_cls: 1.9701 - detector_regr: 0.4413Average number of overlapping bounding boxes from RPN = 20.363333333333333 for 300 previous iterations
# 300/300 [==============================] - 94s 314ms/step - rpn_cls: 1.4198 - rpn_regr: 0.1389 - detector_cls: 1.9702 - detector_regr: 0.4413
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.3421926910299
# Classifier accuracy for bounding boxes from RPN: 0.5316666666666666
# Loss RPN classifier: 1.5454015870633835
# Loss RPN regression: 0.13994156047080955
# Loss Detector classifier: 1.976816708445549
# Loss Detector regression: 0.44508863518635433
# Elapsed time: 94.72390937805176[s]
# Total loss decreased from 4.604706780755869 to 4.1072484911660965, saving weights
# Epoch 6/20
#  99/300 [========>.....................] - ETA: 1:04 - rpn_cls: 1.2441 - rpn_regr: 0.1303 - detector_cls: 2.0289 - detector_regr: 0.5100Exception: 'NoneType' object is not subscriptable
# 203/300 [===================>..........] - ETA: 29s - rpn_cls: 1.4508 - rpn_regr: 0.1381 - detector_cls: 2.0158 - detector_regr: 0.5016Exception: 'NoneType' object is not subscriptable
# 270/300 [==========================>...] - ETA: 9s - rpn_cls: 1.4473 - rpn_regr: 0.1383 - detector_cls: 2.0097 - detector_regr: 0.4987Exception: 'NoneType' object is not subscriptable
# 295/300 [============================>.] - ETA: 1s - rpn_cls: 1.4517 - rpn_regr: 0.1383 - detector_cls: 2.0078 - detector_regr: 0.4973Average number of overlapping bounding boxes from RPN = 21.423333333333332 for 300 previous iterations
# 300/300 [==============================] - 93s 310ms/step - rpn_cls: 1.4522 - rpn_regr: 0.1383 - detector_cls: 2.0076 - detector_regr: 0.4970
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.64784053156146
# Classifier accuracy for bounding boxes from RPN: 0.52
# Loss RPN classifier: 1.485519369000973
# Loss RPN regression: 0.1372105204112207
# Loss Detector classifier: 1.9967247544725737
# Loss Detector regression: 0.480858080809315
# Elapsed time: 93.66321921348572[s]
# Total loss decreased from 4.1072484911660965 to 4.100312724694082, saving weights
# Epoch 7/20
#  81/300 [=======>......................] - ETA: 1:11 - rpn_cls: 1.3366 - rpn_regr: 0.1651 - detector_cls: 2.0704 - detector_regr: 0.4604Exception: 'NoneType' object is not subscriptable
# 294/300 [============================>.] - ETA: 1s - rpn_cls: 1.4293 - rpn_regr: 0.1538 - detector_cls: 1.9694 - detector_regr: 0.4413Average number of overlapping bounding boxes from RPN = 20.84 for 300 previous iterations
# 300/300 [==============================] - 92s 307ms/step - rpn_cls: 1.4326 - rpn_regr: 0.1536 - detector_cls: 1.9680 - detector_regr: 0.4412
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.631229235880397
# Classifier accuracy for bounding boxes from RPN: 0.5233333333333333
# Loss RPN classifier: 1.580343054300335
# Loss RPN regression: 0.14565585773438217
# Loss Detector classifier: 1.9010792614022891
# Loss Detector regression: 0.4360121354709069
# Elapsed time: 93.27381777763367[s]
# Total loss decreased from 4.100312724694082 to 4.063090308907913, saving weights
# Epoch 8/20
# 210/300 [====================>.........] - ETA: 29s - rpn_cls: 1.1734 - rpn_regr: 0.1383 - detector_cls: 1.9868 - detector_regr: 0.4330Exception: 'NoneType' object is not subscriptable
# 293/300 [============================>.] - ETA: 2s - rpn_cls: 1.2458 - rpn_regr: 0.1394 - detector_cls: 1.9735 - detector_regr: 0.4342Average number of overlapping bounding boxes from RPN = 21.17 for 300 previous iterations
# 300/300 [==============================] - 97s 322ms/step - rpn_cls: 1.2496 - rpn_regr: 0.1395 - detector_cls: 1.9728 - detector_regr: 0.4344
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.162790697674417
# Classifier accuracy for bounding boxes from RPN: 0.5241666666666667
# Loss RPN classifier: 1.4160208051041754
# Loss RPN regression: 0.14335052031092346
# Loss Detector classifier: 1.9463337700565655
# Loss Detector regression: 0.4386284933735927
# Elapsed time: 97.34762692451477[s]
# Total loss decreased from 4.063090308907913 to 3.944333588845257, saving weights
# Epoch 9/20
#  52/300 [====>.........................] - ETA: 1:14 - rpn_cls: 1.2337 - rpn_regr: 0.1150 - detector_cls: 1.8325 - detector_regr: 0.4224Exception: 'NoneType' object is not subscriptable
# 120/300 [===========>..................] - ETA: 56s - rpn_cls: 1.4739 - rpn_regr: 0.1081 - detector_cls: 1.8898 - detector_regr: 0.4227Exception: 'NoneType' object is not subscriptable
# 155/300 [==============>...............] - ETA: 47s - rpn_cls: 1.5235 - rpn_regr: 0.1093 - detector_cls: 1.8987 - detector_regr: 0.4201Exception: 'NoneType' object is not subscriptable
# 215/300 [====================>.........] - ETA: 27s - rpn_cls: 1.5856 - rpn_regr: 0.1123 - detector_cls: 1.9064 - detector_regr: 0.4165Exception: 'NoneType' object is not subscriptable
# 249/300 [=======================>......] - ETA: 16s - rpn_cls: 1.5941 - rpn_regr: 0.1135 - detector_cls: 1.9091 - detector_regr: 0.4165Exception: 'NoneType' object is not subscriptable
# 292/300 [============================>.] - ETA: 2s - rpn_cls: 1.6002 - rpn_regr: 0.1145 - detector_cls: 1.9118 - detector_regr: 0.4165Average number of overlapping bounding boxes from RPN = 21.74 for 300 previous iterations
# 300/300 [==============================] - 96s 319ms/step - rpn_cls: 1.6011 - rpn_regr: 0.1146 - detector_cls: 1.9119 - detector_regr: 0.4165
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.727574750830566
# Classifier accuracy for bounding boxes from RPN: 0.5266666666666666
# Loss RPN classifier: 1.621106378329448
# Loss RPN regression: 0.1209335347233961
# Loss Detector classifier: 1.9125834600130718
# Loss Detector regression: 0.4144094471136729
# Elapsed time: 96.32396364212036[s]
# Epoch 10/20
# 157/300 [==============>...............] - ETA: 46s - rpn_cls: 1.8575 - rpn_regr: 0.1392 - detector_cls: 1.7858 - detector_regr: 0.4204Exception: 'NoneType' object is not subscriptable
# 177/300 [================>.............] - ETA: 40s - rpn_cls: 1.8244 - rpn_regr: 0.1380 - detector_cls: 1.7821 - detector_regr: 0.4186Exception: 'NoneType' object is not subscriptable
# 206/300 [===================>..........] - ETA: 30s - rpn_cls: 1.7843 - rpn_regr: 0.1368 - detector_cls: 1.7791 - detector_regr: 0.4167Exception: 'NoneType' object is not subscriptable
# 216/300 [====================>.........] - ETA: 27s - rpn_cls: 1.7723 - rpn_regr: 0.1366 - detector_cls: 1.7782 - detector_regr: 0.4158Exception: 'NoneType' object is not subscriptable
# 291/300 [============================>.] - ETA: 2s - rpn_cls: 1.7061 - rpn_regr: 0.1361 - detector_cls: 1.7710 - detector_regr: 0.4113Average number of overlapping bounding boxes from RPN = 20.66 for 300 previous iterations
# 300/300 [==============================] - 97s 324ms/step - rpn_cls: 1.7023 - rpn_regr: 0.1360 - detector_cls: 1.7699 - detector_regr: 0.4109
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.631229235880397
# Classifier accuracy for bounding boxes from RPN: 0.53
# Loss RPN classifier: 1.5775530153988782
# Loss RPN regression: 0.13467933519432942
# Loss Detector classifier: 1.734188203016917
# Loss Detector regression: 0.39766382791101934
# Elapsed time: 97.57092452049255[s]
# Total loss decreased from 3.944333588845257 to 3.844084381521144, saving weights
# Epoch 11/20
# 290/300 [============================>.] - ETA: 3s - rpn_cls: 1.6299 - rpn_regr: 0.1258 - detector_cls: 1.7838 - detector_regr: 0.3914Average number of overlapping bounding boxes from RPN = 22.03 for 300 previous iterations
# 300/300 [==============================] - 95s 316ms/step - rpn_cls: 1.6266 - rpn_regr: 0.1256 - detector_cls: 1.7839 - detector_regr: 0.3913
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.953488372093023
# Classifier accuracy for bounding boxes from RPN: 0.5291666666666667
# Loss RPN classifier: 1.5078624838428303
# Loss RPN regression: 0.1228482308300833
# Loss Detector classifier: 1.7856911940375964
# Loss Detector regression: 0.392005597576499
# Elapsed time: 95.24424505233765[s]
# Total loss decreased from 3.844084381521144 to 3.808407506287009, saving weights
# Epoch 12/20
# 216/300 [====================>.........] - ETA: 25s - rpn_cls: 1.0944 - rpn_regr: 0.1113 - detector_cls: 1.7742 - detector_regr: 0.3498Exception: 'NoneType' object is not subscriptable
# 259/300 [========================>.....] - ETA: 12s - rpn_cls: 1.1442 - rpn_regr: 0.1110 - detector_cls: 1.7701 - detector_regr: 0.3521Exception: 'NoneType' object is not subscriptable
# 276/300 [==========================>...] - ETA: 7s - rpn_cls: 1.1677 - rpn_regr: 0.1110 - detector_cls: 1.7681 - detector_regr: 0.3527Exception: 'NoneType' object is not subscriptable
# 289/300 [===========================>..] - ETA: 3s - rpn_cls: 1.1848 - rpn_regr: 0.1110 - detector_cls: 1.7671 - detector_regr: 0.3531Average number of overlapping bounding boxes from RPN = 23.043333333333333 for 300 previous iterations
# 292/300 [============================>.] - ETA: 2s - rpn_cls: 1.1883 - rpn_regr: 0.1110 - detector_cls: 1.7668 - detector_regr: 0.3532Exception: 'NoneType' object is not subscriptable
# 300/300 [==============================] - 93s 312ms/step - rpn_cls: 1.1965 - rpn_regr: 0.1110 - detector_cls: 1.7662 - detector_regr: 0.3534
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.3953488372093
# Classifier accuracy for bounding boxes from RPN: 0.5166666666666667
# Loss RPN classifier: 1.486362956580416
# Loss RPN regression: 0.11048226703268786
# Loss Detector classifier: 1.7416689059138297
# Loss Detector regression: 0.3615800067906578
# Elapsed time: 94.11767864227295[s]
# Total loss decreased from 3.808407506287009 to 3.7000941363175914, saving weights
# Epoch 13/20
# 242/300 [=======================>......] - ETA: 19s - rpn_cls: 1.3439 - rpn_regr: 0.1144 - detector_cls: 1.6699 - detector_regr: 0.3797Exception: 'NoneType' object is not subscriptable
# 288/300 [===========================>..] - ETA: 3s - rpn_cls: 1.3761 - rpn_regr: 0.1161 - detector_cls: 1.6773 - detector_regr: 0.3781Average number of overlapping bounding boxes from RPN = 20.93 for 300 previous iterations
# 300/300 [==============================] - 98s 328ms/step - rpn_cls: 1.3853 - rpn_regr: 0.1164 - detector_cls: 1.6790 - detector_regr: 0.3777
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.674418604651162
# Classifier accuracy for bounding boxes from RPN: 0.5291666666666667
# Loss RPN classifier: 1.5933747284222088
# Loss RPN regression: 0.12356214536353946
# Loss Detector classifier: 1.721355500817299
# Loss Detector regression: 0.3679300089056293
# Elapsed time: 99.11049103736877[s]
# Epoch 14/20
#   1/300 [..............................] - ETA: 1:29 - rpn_cls: 4.5298e-05 - rpn_regr: 0.1049 - detector_cls: 2.0462 - detector_regr: 0.4531Exception: 'NoneType' object is not subscriptable
# 287/300 [===========================>..] - ETA: 4s - rpn_cls: 1.3973 - rpn_regr: 0.1289 - detector_cls: 1.7673 - detector_regr: 0.3716Average number of overlapping bounding boxes from RPN = 21.83 for 300 previous iterations
# 300/300 [==============================] - 94s 313ms/step - rpn_cls: 1.4011 - rpn_regr: 0.1289 - detector_cls: 1.7689 - detector_regr: 0.3708
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.106312292358805
# Classifier accuracy for bounding boxes from RPN: 0.5225
# Loss RPN classifier: 1.4724794228848586
# Loss RPN regression: 0.1271825366591414
# Loss Detector classifier: 1.8049414027730624
# Loss Detector regression: 0.35248422789076966
# Elapsed time: 94.0343108177185[s]
# Epoch 15/20
#  38/300 [==>...........................] - ETA: 1:20 - rpn_cls: 1.2558 - rpn_regr: 0.1104 - detector_cls: 1.7021 - detector_regr: 0.2952Exception: 'NoneType' object is not subscriptable
#  52/300 [====>.........................] - ETA: 1:17 - rpn_cls: 1.3360 - rpn_regr: 0.1133 - detector_cls: 1.6856 - detector_regr: 0.2994Exception: 'NoneType' object is not subscriptable
# 286/300 [===========================>..] - ETA: 4s - rpn_cls: 1.5393 - rpn_regr: 0.1236 - detector_cls: 1.7020 - detector_regr: 0.3345Average number of overlapping bounding boxes from RPN = 21.993333333333332 for 300 previous iterations
# 292/300 [============================>.] - ETA: 2s - rpn_cls: 1.5398 - rpn_regr: 0.1235 - detector_cls: 1.7018 - detector_regr: 0.3346Exception: 'NoneType' object is not subscriptable
# 300/300 [==============================] - 93s 308ms/step - rpn_cls: 1.5396 - rpn_regr: 0.1236 - detector_cls: 1.7017 - detector_regr: 0.3347
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.72093023255814
# Classifier accuracy for bounding boxes from RPN: 0.5325
# Loss RPN classifier: 1.5143364522547067
# Loss RPN regression: 0.12358447608072311
# Loss Detector classifier: 1.6962413222591082
# Loss Detector regression: 0.3404686027765274
# Elapsed time: 92.8638904094696[s]
# Total loss decreased from 3.7000941363175914 to 3.6746308533710654, saving weights
# Epoch 16/20
# 121/300 [===========>..................] - ETA: 53s - rpn_cls: 1.5045 - rpn_regr: 0.1229 - detector_cls: 1.7193 - detector_regr: 0.3209Exception: 'NoneType' object is not subscriptable
# 203/300 [===================>..........] - ETA: 29s - rpn_cls: 1.5147 - rpn_regr: 0.1255 - detector_cls: 1.6994 - detector_regr: 0.3288Exception: 'NoneType' object is not subscriptable
# 245/300 [=======================>......] - ETA: 16s - rpn_cls: 1.5282 - rpn_regr: 0.1256 - detector_cls: 1.6917 - detector_regr: 0.3307Exception: 'NoneType' object is not subscriptable
# 285/300 [===========================>..] - ETA: 4s - rpn_cls: 1.5240 - rpn_regr: 0.1252 - detector_cls: 1.6853 - detector_regr: 0.3322Average number of overlapping bounding boxes from RPN = 21.786666666666665 for 300 previous iterations
# 300/300 [==============================] - 91s 305ms/step - rpn_cls: 1.5207 - rpn_regr: 0.1251 - detector_cls: 1.6842 - detector_regr: 0.3327
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.916943521594686
# Classifier accuracy for bounding boxes from RPN: 0.5425
# Loss RPN classifier: 1.4449253909750341
# Loss RPN regression: 0.12262401581276208
# Loss Detector classifier: 1.666135574330886
# Loss Detector regression: 0.34277012179295224
# Elapsed time: 92.0962655544281[s]
# Total loss decreased from 3.6746308533710654 to 3.576455102911635, saving weights
# Epoch 17/20
# 271/300 [==========================>...] - ETA: 8s - rpn_cls: 2.2130 - rpn_regr: 0.1207 - detector_cls: 1.7043 - detector_regr: 0.3464Exception: 'NoneType' object is not subscriptable
# 284/300 [===========================>..] - ETA: 4s - rpn_cls: 2.2116 - rpn_regr: 0.1207 - detector_cls: 1.7024 - detector_regr: 0.3462Average number of overlapping bounding boxes from RPN = 20.483333333333334 for 300 previous iterations
# 300/300 [==============================] - 93s 311ms/step - rpn_cls: 2.2088 - rpn_regr: 0.1206 - detector_cls: 1.7007 - detector_regr: 0.3460
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.47840531561462
# Classifier accuracy for bounding boxes from RPN: 0.54
# Loss RPN classifier: 2.1242381560049313
# Loss RPN regression: 0.11859750465179483
# Loss Detector classifier: 1.6681881581743558
# Loss Detector regression: 0.3413023253281911
# Elapsed time: 93.84656238555908[s]
# Epoch 18/20
# 129/300 [===========>..................] - ETA: 54s - rpn_cls: 1.3113 - rpn_regr: 0.0970 - detector_cls: 1.6839 - detector_regr: 0.3818Exception: 'NoneType' object is not subscriptable
# 276/300 [==========================>...] - ETA: 7s - rpn_cls: 1.3905 - rpn_regr: 0.1018 - detector_cls: 1.6239 - detector_regr: 0.3606Exception: 'NoneType' object is not subscriptable
# 283/300 [===========================>..] - ETA: 5s - rpn_cls: 1.3908 - rpn_regr: 0.1020 - detector_cls: 1.6224 - detector_regr: 0.3600Average number of overlapping bounding boxes from RPN = 23.273333333333333 for 300 previous iterations
# 300/300 [==============================] - 94s 313ms/step - rpn_cls: 1.3926 - rpn_regr: 0.1024 - detector_cls: 1.6192 - detector_regr: 0.3588
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.385382059800666
# Classifier accuracy for bounding boxes from RPN: 0.5441666666666667
# Loss RPN classifier: 1.4162429290646779
# Loss RPN regression: 0.11004634104669093
# Loss Detector classifier: 1.5647608193010092
# Loss Detector regression: 0.34114340496559936
# Elapsed time: 94.3323974609375[s]
# Total loss decreased from 3.576455102911635 to 3.4321934943779775, saving weights
# Epoch 19/20
#  21/300 [=>............................] - ETA: 1:25 - rpn_cls: 1.8328 - rpn_regr: 0.0924 - detector_cls: 1.8767 - detector_regr: 0.2643Exception: 'NoneType' object is not subscriptable
#  51/300 [====>.........................] - ETA: 1:15 - rpn_cls: 1.5661 - rpn_regr: 0.1001 - detector_cls: 1.8358 - detector_regr: 0.3187Exception: 'NoneType' object is not subscriptable
# 183/300 [=================>............] - ETA: 36s - rpn_cls: 1.3329 - rpn_regr: 0.1079 - detector_cls: 1.7398 - detector_regr: 0.3403Exception: 'NoneType' object is not subscriptable
# 282/300 [===========================>..] - ETA: 5s - rpn_cls: 1.3020 - rpn_regr: 0.1084 - detector_cls: 1.7146 - detector_regr: 0.3422Average number of overlapping bounding boxes from RPN = 23.546666666666667 for 300 previous iterations
# 300/300 [==============================] - 95s 317ms/step - rpn_cls: 1.3049 - rpn_regr: 0.1084 - detector_cls: 1.7120 - detector_regr: 0.3426
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.40199335548173
# Classifier accuracy for bounding boxes from RPN: 0.5258333333333334
# Loss RPN classifier: 1.344349320573176
# Loss RPN regression: 0.10901926802781721
# Loss Detector classifier: 1.6681643020113308
# Loss Detector regression: 0.3465516179675857
# Elapsed time: 95.61938548088074[s]
# Epoch 20/20
#  96/300 [========>.....................] - ETA: 1:02 - rpn_cls: 1.2944 - rpn_regr: 0.0987 - detector_cls: 1.6270 - detector_regr: 0.3312Exception: 'NoneType' object is not subscriptable
# 281/300 [===========================>..] - ETA: 5s - rpn_cls: 1.4659 - rpn_regr: 0.1040 - detector_cls: 1.6117 - detector_regr: 0.3401Average number of overlapping bounding boxes from RPN = 24.163333333333334 for 300 previous iterations
# 300/300 [==============================] - 94s 313ms/step - rpn_cls: 1.4619 - rpn_regr: 0.1041 - detector_cls: 1.6129 - detector_regr: 0.3396
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.993355481727576
# Classifier accuracy for bounding boxes from RPN: 0.5475
# Loss RPN classifier: 1.3661471637474136
# Loss RPN regression: 0.10626439166876177
# Loss Detector classifier: 1.6304476895928384
# Loss Detector regression: 0.3296091104174654
# Elapsed time: 94.0846426486969[s]
# training is done
# -------------------------------
# path to config file : ./save\train_20190313-122253_config.pickle
# -------------------------------

# %% [markdown]
# 推定

# %% [markdown]
# 以下のコマンドを実行してください。
#
# python predict.py -i [推定したい画像を入れたディレクトリのパス] -c [学習時に保存された設定ファイルのパス]

# %%
# %run predict.py -i kaggle_simpson_testset -c ./save/train_20190313-122253_config.pickle
# Out:
# abraham_grampa_simpson_0.jpg
# [('marge_simpson', 56.28582835197449)]
# Elapsed time = 2.745004415512085[s]
# abraham_grampa_simpson_1.jpg
# []
# Elapsed time = 0.7948734760284424[s]
# abraham_grampa_simpson_10.jpg
# []
# Elapsed time = 0.8237979412078857[s]
# abraham_grampa_simpson_11.jpg
# []
# Elapsed time = 0.8158214092254639[s]
# abraham_grampa_simpson_12.jpg
# [('krusty_the_clown', 56.18165731430054)]
# Elapsed time = 0.8277552127838135[s]
# abraham_grampa_simpson_13.jpg
# [('krusty_the_clown', 55.18215298652649)]
# Elapsed time = 0.8287639617919922[s]
# abraham_grampa_simpson_14.jpg
# []
# Elapsed time = 0.767916202545166[s]
# abraham_grampa_simpson_15.jpg
# []
# Elapsed time = 0.8138511180877686[s]
# abraham_grampa_simpson_16.jpg
# [('marge_simpson', 56.5295934677124)]
# Elapsed time = 0.8088369369506836[s]
# abraham_grampa_simpson_17.jpg
# []
# Elapsed time = 0.7559735774993896[s]
# abraham_grampa_simpson_18.jpg
# []
# Elapsed time = 0.8267641067504883[s]
# abraham_grampa_simpson_19.jpg
# [('krusty_the_clown', 58.86806845664978)]
# Elapsed time = 0.814854621887207[s]
# abraham_grampa_simpson_2.jpg
# [('krusty_the_clown', 55.506664514541626)]
# Elapsed time = 0.8597259521484375[s]
# abraham_grampa_simpson_20.jpg
# []
# Elapsed time = 0.9325337409973145[s]
# abraham_grampa_simpson_21.jpg
# []
# Elapsed time = 0.8098094463348389[s]
# abraham_grampa_simpson_22.jpg
# []
# Elapsed time = 0.869661808013916[s]
# abraham_grampa_simpson_23.jpg
# []
# Elapsed time = 0.82476806640625[s]
# abraham_grampa_simpson_24.jpg
# []
# Elapsed time = 0.8347625732421875[s]
# abraham_grampa_simpson_25.jpg
# []
# Elapsed time = 0.8098022937774658[s]
# abraham_grampa_simpson_26.jpg
# []
# Elapsed time = 0.8177931308746338[s]
# abraham_grampa_simpson_27.jpg
# []
# Elapsed time = 0.8796191215515137[s]
# abraham_grampa_simpson_28.jpg
# []
# Elapsed time = 0.8586771488189697[s]
# abraham_grampa_simpson_29.jpg
# []
# Elapsed time = 0.8457129001617432[s]
# abraham_grampa_simpson_3.jpg
# [('marge_simpson', 68.12136173248291)]
# Elapsed time = 0.7898898124694824[s]
# abraham_grampa_simpson_30.jpg
# []
# Elapsed time = 0.8257942199707031[s]
# abraham_grampa_simpson_31.jpg
# []
# Elapsed time = 0.822812557220459[s]
# abraham_grampa_simpson_32.jpg
# []
# Elapsed time = 0.819807767868042[s]
# abraham_grampa_simpson_33.jpg
# []
# Elapsed time = 0.8128273487091064[s]
# abraham_grampa_simpson_34.jpg
# []
# Elapsed time = 0.8227851390838623[s]
# abraham_grampa_simpson_35.jpg
# []
# Elapsed time = 0.8317341804504395[s]
# abraham_grampa_simpson_36.jpg
# []
# Elapsed time = 0.901564359664917[s]
# abraham_grampa_simpson_37.jpg
# []
# Elapsed time = 0.9364972114562988[s]
# abraham_grampa_simpson_38.jpg
# []
# Elapsed time = 0.8716726303100586[s]
# abraham_grampa_simpson_39.jpg
# []
# Elapsed time = 0.8836281299591064[s]
# abraham_grampa_simpson_4.jpg
# []
# Elapsed time = 0.7898621559143066[s]
# abraham_grampa_simpson_40.jpg
# []
# Elapsed time = 0.8128001689910889[s]
# abraham_grampa_simpson_41.jpg
# []
# Elapsed time = 0.8317508697509766[s]
# abraham_grampa_simpson_42.jpg
# []
# Elapsed time = 0.9085714817047119[s]
# abraham_grampa_simpson_43.jpg
# []
# Elapsed time = 0.85671067237854[s]
# abraham_grampa_simpson_44.jpg
# []
# Elapsed time = 0.7849001884460449[s]
# abraham_grampa_simpson_45.jpg
# []
# Elapsed time = 0.8257880210876465[s]
# abraham_grampa_simpson_46.jpg
# []
# Elapsed time = 0.8248002529144287[s]
# abraham_grampa_simpson_47.jpg
# []
# Elapsed time = 0.8267602920532227[s]
# abraham_grampa_simpson_48.jpg
# []
# Elapsed time = 0.876631498336792[s]
# abraham_grampa_simpson_49.jpg
# []
# Elapsed time = 0.8297805786132812[s]
# abraham_grampa_simpson_7.jpg
# []
# Elapsed time = 0.922534704208374[s]
# abraham_grampa_simpson_8.jpg
# []
# Elapsed time = 0.855687141418457[s]
# abraham_grampa_simpson_9.jpg
# []
# Elapsed time = 0.864656925201416[s]
# apu_nahasapeemapetilon_0.jpg
# []
# Elapsed time = 0.820807695388794[s]
# apu_nahasapeemapetilon_1.jpg
# [('krusty_the_clown', 57.94267654418945)]
# Elapsed time = 1.382326602935791[s]
# apu_nahasapeemapetilon_10.jpg
# []
# Elapsed time = 0.796844482421875[s]
# apu_nahasapeemapetilon_11.jpg
# [('marge_simpson', 55.79993724822998)]
# Elapsed time = 0.8048474788665771[s]
# apu_nahasapeemapetilon_12.jpg
# []
# Elapsed time = 0.8267908096313477[s]
# apu_nahasapeemapetilon_13.jpg
# []
# Elapsed time = 0.833747148513794[s]
# apu_nahasapeemapetilon_14.jpg
# []
# Elapsed time = 0.8237977027893066[s]
# apu_nahasapeemapetilon_15.jpg
# []
# Elapsed time = 0.8098351955413818[s]
# apu_nahasapeemapetilon_16.jpg
# []
# Elapsed time = 0.8158278465270996[s]
# apu_nahasapeemapetilon_17.jpg
# []
# Elapsed time = 0.7440118789672852[s]
# apu_nahasapeemapetilon_18.jpg
# []
# Elapsed time = 0.8118026256561279[s]
# apu_nahasapeemapetilon_19.jpg
# []
# Elapsed time = 0.8198087215423584[s]
# apu_nahasapeemapetilon_2.jpg
# []
# Elapsed time = 0.7410192489624023[s]
# apu_nahasapeemapetilon_20.jpg
# []
# Elapsed time = 0.8198091983795166[s]
# apu_nahasapeemapetilon_21.jpg
# []
# Elapsed time = 0.7669486999511719[s]
# apu_nahasapeemapetilon_22.jpg
# []
# Elapsed time = 0.8208057880401611[s]
# apu_nahasapeemapetilon_23.jpg
# []
# Elapsed time = 0.8327734470367432[s]
# apu_nahasapeemapetilon_24.jpg
# []
# Elapsed time = 0.8038690090179443[s]
# apu_nahasapeemapetilon_25.jpg
# []
# Elapsed time = 0.7779202461242676[s]
# apu_nahasapeemapetilon_26.jpg
# []
# Elapsed time = 0.8138256072998047[s]
# apu_nahasapeemapetilon_27.jpg
# [('marge_simpson', 60.50030589103699), ('krusty_the_clown', 58.44161510467529)]
# Elapsed time = 0.7510206699371338[s]
# apu_nahasapeemapetilon_28.jpg
# []
# Elapsed time = 0.8197789192199707[s]
# apu_nahasapeemapetilon_29.jpg
# []
# Elapsed time = 0.8118298053741455[s]
# apu_nahasapeemapetilon_3.jpg
# []
# Elapsed time = 0.8696503639221191[s]
# apu_nahasapeemapetilon_30.jpg
# [('krusty_the_clown', 59.17843580245972)]
# Elapsed time = 1.425161361694336[s]
# apu_nahasapeemapetilon_31.jpg
# []
# Elapsed time = 0.782912015914917[s]
# apu_nahasapeemapetilon_32.jpg
# []
# Elapsed time = 0.8696691989898682[s]
# apu_nahasapeemapetilon_33.jpg
# [('marge_simpson', 64.55345749855042)]
# Elapsed time = 0.7839052677154541[s]
# apu_nahasapeemapetilon_34.jpg
# []
# Elapsed time = 0.8078403472900391[s]
# apu_nahasapeemapetilon_35.jpg
# []
# Elapsed time = 0.7170839309692383[s]
# apu_nahasapeemapetilon_36.jpg
# [('marge_simpson', 59.64364409446716)]
# Elapsed time = 0.7888920307159424[s]
# apu_nahasapeemapetilon_37.jpg
# []
# Elapsed time = 0.8118126392364502[s]
# apu_nahasapeemapetilon_38.jpg
# []
# Elapsed time = 0.826789140701294[s]
# apu_nahasapeemapetilon_39.jpg
# []
# Elapsed time = 0.7839043140411377[s]
# apu_nahasapeemapetilon_4.jpg
# []
# Elapsed time = 0.8377339839935303[s]
# apu_nahasapeemapetilon_40.jpg
# [('chief_wiggum', 66.28360152244568)]
# Elapsed time = 0.8068759441375732[s]
# apu_nahasapeemapetilon_41.jpg
# []
# Elapsed time = 0.7798881530761719[s]
# apu_nahasapeemapetilon_42.jpg
# []
# Elapsed time = 0.80784010887146[s]
# apu_nahasapeemapetilon_43.jpg
# []
# Elapsed time = 0.7839059829711914[s]
# apu_nahasapeemapetilon_44.jpg
# [('marge_simpson', 73.60941767692566)]
# Elapsed time = 0.8188126087188721[s]
# apu_nahasapeemapetilon_45.jpg
# []
# Elapsed time = 0.8327462673187256[s]
# apu_nahasapeemapetilon_46.jpg
# []
# Elapsed time = 0.8098354339599609[s]
# apu_nahasapeemapetilon_47.jpg
# []
# Elapsed time = 0.7539844512939453[s]
# apu_nahasapeemapetilon_48.jpg
# []
# Elapsed time = 0.8107986450195312[s]
# apu_nahasapeemapetilon_49.jpg
# []
# Elapsed time = 0.7779340744018555[s]
# apu_nahasapeemapetilon_5.jpg
# []
# Elapsed time = 0.8168168067932129[s]
# apu_nahasapeemapetilon_6.jpg
# [('krusty_the_clown', 60.35417914390564)]
# Elapsed time = 0.7380275726318359[s]
# apu_nahasapeemapetilon_7.jpg
# []
# Elapsed time = 0.8237979412078857[s]
# apu_nahasapeemapetilon_8.jpg
# []
# Elapsed time = 0.7450084686279297[s]
# apu_nahasapeemapetilon_9.jpg
# []
# Elapsed time = 0.8237981796264648[s]
# bart_simpson_0.jpg
# []
# Elapsed time = 0.742018461227417[s]
# bart_simpson_1.jpg
# []
# Elapsed time = 0.7819101810455322[s]
# bart_simpson_10.jpg
# []
# Elapsed time = 0.7948880195617676[s]
# bart_simpson_11.jpg
# []
# Elapsed time = 0.8208057880401611[s]
# bart_simpson_12.jpg
# []
# Elapsed time = 0.8237981796264648[s]
# bart_simpson_13.jpg
# []
# Elapsed time = 0.7799153327941895[s]
# bart_simpson_14.jpg
# [('marge_simpson', 67.0255959033966)]
# Elapsed time = 0.7958738803863525[s]
# bart_simpson_15.jpg
# []
# Elapsed time = 0.8547146320343018[s]
# bart_simpson_16.jpg
# []
# Elapsed time = 0.8287835121154785[s]
# bart_simpson_17.jpg
# []
# Elapsed time = 0.8058450222015381[s]
# bart_simpson_18.jpg
# []
# Elapsed time = 0.9165468215942383[s]
# bart_simpson_19.jpg
# []
# Elapsed time = 0.7928807735443115[s]
# bart_simpson_2.jpg
# []
# Elapsed time = 0.8178141117095947[s]
# bart_simpson_20.jpg
# []
# Elapsed time = 0.824800968170166[s]
# bart_simpson_21.jpg
# [('marge_simpson', 78.57674956321716)]
# Elapsed time = 0.9035837650299072[s]
# bart_simpson_22.jpg
# [('marge_simpson', 58.18133354187012)]
# Elapsed time = 0.9325079917907715[s]
# bart_simpson_23.jpg
# []
# Elapsed time = 0.7948894500732422[s]
# bart_simpson_24.jpg
# []
# Elapsed time = 0.8766560554504395[s]
# bart_simpson_25.jpg
# []
# Elapsed time = 0.8517069816589355[s]
# bart_simpson_26.jpg
# []
# Elapsed time = 0.8437440395355225[s]
# bart_simpson_27.jpg
# []
# Elapsed time = 0.8187830448150635[s]
# bart_simpson_28.jpg
# [('krusty_the_clown', 59.32878851890564)]
# Elapsed time = 0.8227989673614502[s]
# bart_simpson_29.jpg
# [('lisa_simpson', 55.10417819023132)]
# Elapsed time = 0.7689440250396729[s]
# bart_simpson_3.jpg
# []
# Elapsed time = 0.8347413539886475[s]
# bart_simpson_30.jpg
# []
# Elapsed time = 0.8447408676147461[s]
# bart_simpson_31.jpg
# []
# Elapsed time = 0.8497283458709717[s]
# bart_simpson_32.jpg
# []
# Elapsed time = 0.8407492637634277[s]
# bart_simpson_33.jpg
# []
# Elapsed time = 0.7629609107971191[s]
# bart_simpson_34.jpg
# [('krusty_the_clown', 55.63814640045166)]
# Elapsed time = 0.7559490203857422[s]
# bart_simpson_35.jpg
# []
# Elapsed time = 0.8188118934631348[s]
# bart_simpson_36.jpg
# []
# Elapsed time = 0.8038506507873535[s]
# bart_simpson_37.jpg
# []
# Elapsed time = 0.7888908386230469[s]
# bart_simpson_38.jpg
# []
# Elapsed time = 0.787883996963501[s]
# bart_simpson_39.jpg
# []
# Elapsed time = 0.8347682952880859[s]
# bart_simpson_4.jpg
# []
# Elapsed time = 0.8497028350830078[s]
# bart_simpson_40.jpg
# []
# Elapsed time = 0.7928805351257324[s]
# bart_simpson_41.jpg
# [('marge_simpson', 75.35989880561829)]
# Elapsed time = 0.7908861637115479[s]
# bart_simpson_42.jpg
# [('krusty_the_clown', 58.59352946281433)]
# Elapsed time = 0.8287551403045654[s]
# bart_simpson_43.jpg
# []
# Elapsed time = 0.8198087215423584[s]
# bart_simpson_44.jpg
# []
# Elapsed time = 0.8257863521575928[s]
# bart_simpson_45.jpg
# [('marge_simpson', 81.42772912979126)]
# Elapsed time = 0.815819501876831[s]
# bart_simpson_46.jpg
# []
# Elapsed time = 0.880645751953125[s]
# bart_simpson_47.jpg
# []
# Elapsed time = 0.8207786083221436[s]
# bart_simpson_48.jpg
# []
# Elapsed time = 0.8597218990325928[s]
# bart_simpson_49.jpg
# []
# Elapsed time = 0.8626930713653564[s]
# bart_simpson_5.jpg
# []
# Elapsed time = 0.8168165683746338[s]
# bart_simpson_6.jpg
# []
# Elapsed time = 0.8616969585418701[s]
# bart_simpson_7.jpg
# [('marge_simpson', 78.57674956321716)]
# Elapsed time = 0.8716678619384766[s]
# bart_simpson_8.jpg
# []
# Elapsed time = 0.8327739238739014[s]
# bart_simpson_9.jpg
# []
# Elapsed time = 0.8656983375549316[s]
# charles_montgomery_burns_0.jpg
# []
# Elapsed time = 0.8746333122253418[s]
# charles_montgomery_burns_1.jpg
# []
# Elapsed time = 0.8088314533233643[s]
# charles_montgomery_burns_10.jpg
# []
# Elapsed time = 0.8865988254547119[s]
# charles_montgomery_burns_11.jpg
# []
# Elapsed time = 0.781912088394165[s]
# charles_montgomery_burns_12.jpg
# [('marge_simpson', 55.13948202133179)]
# Elapsed time = 0.8457362651824951[s]
# charles_montgomery_burns_13.jpg
# []
# Elapsed time = 0.8516960144042969[s]
# charles_montgomery_burns_14.jpg
# []
# Elapsed time = 0.878650426864624[s]
# charles_montgomery_burns_15.jpg
# [('marge_simpson', 55.13948202133179)]
# Elapsed time = 0.8008339405059814[s]
# charles_montgomery_burns_16.jpg
# []
# Elapsed time = 0.8247950077056885[s]
# charles_montgomery_burns_17.jpg
# []
# Elapsed time = 0.8586935997009277[s]
# charles_montgomery_burns_18.jpg
# [('krusty_the_clown', 60.36142706871033)]
# Elapsed time = 0.7609663009643555[s]
# charles_montgomery_burns_19.jpg
# []
# Elapsed time = 0.8407495021820068[s]
# charles_montgomery_burns_2.jpg
# []
# Elapsed time = 0.8168165683746338[s]
# charles_montgomery_burns_20.jpg
# []
# Elapsed time = 0.7799153327941895[s]
# charles_montgomery_burns_21.jpg
# []
# Elapsed time = 0.854717493057251[s]
# charles_montgomery_burns_22.jpg
# []
# Elapsed time = 0.8616979122161865[s]
# charles_montgomery_burns_24.jpg
# []
# Elapsed time = 0.8008592128753662[s]
# charles_montgomery_burns_25.jpg
# []
# Elapsed time = 0.8876252174377441[s]
# charles_montgomery_burns_26.jpg
# [('chief_wiggum', 62.308961153030396)]
# Elapsed time = 0.8537187576293945[s]
# charles_montgomery_burns_27.jpg
# []
# Elapsed time = 0.8103542327880859[s]
# charles_montgomery_burns_28.jpg
# [('chief_wiggum', 59.82874631881714), ('marge_simpson', 57.145947217941284)]
# Elapsed time = 0.8839285373687744[s]
# charles_montgomery_burns_29.jpg
# []
# Elapsed time = 0.8419923782348633[s]
# charles_montgomery_burns_3.jpg
# []
# Elapsed time = 0.9243109226226807[s]
# charles_montgomery_burns_30.jpg
# []
# Elapsed time = 0.9315097332000732[s]
# charles_montgomery_burns_31.jpg
# []
# Elapsed time = 0.8255929946899414[s]
# charles_montgomery_burns_32.jpg
# []
# Elapsed time = 0.8545994758605957[s]
# charles_montgomery_burns_33.jpg
# []
# Elapsed time = 0.8485493659973145[s]
# charles_montgomery_burns_34.jpg
# [('marge_simpson', 82.23366141319275)]
# Elapsed time = 0.8517105579376221[s]
# charles_montgomery_burns_35.jpg
# []
# Elapsed time = 0.8501107692718506[s]
# charles_montgomery_burns_36.jpg
# []
# Elapsed time = 0.8329808712005615[s]
# charles_montgomery_burns_37.jpg
# []
# Elapsed time = 0.8856964111328125[s]
# charles_montgomery_burns_38.jpg
# []
# Elapsed time = 0.8262977600097656[s]
# charles_montgomery_burns_39.jpg
# []
# Elapsed time = 0.8326199054718018[s]
# charles_montgomery_burns_4.jpg
# []
# Elapsed time = 0.9081039428710938[s]
# charles_montgomery_burns_40.jpg
# []
# Elapsed time = 0.8502898216247559[s]
# charles_montgomery_burns_41.jpg
# []
# Elapsed time = 0.809302568435669[s]
# charles_montgomery_burns_43.jpg
# []
# Elapsed time = 0.896385669708252[s]
# charles_montgomery_burns_44.jpg
# []
# Elapsed time = 0.846118688583374[s]
# charles_montgomery_burns_45.jpg
# []
# Elapsed time = 0.8643052577972412[s]
# charles_montgomery_burns_46.jpg
# []
# Elapsed time = 0.8367960453033447[s]
# charles_montgomery_burns_47.jpg
# []
# Elapsed time = 0.7885637283325195[s]
# charles_montgomery_burns_48.jpg
# []
# Elapsed time = 0.8858726024627686[s]
# charles_montgomery_burns_49.jpg
# [('marge_simpson', 80.88481426239014)]
# Elapsed time = 0.8576962947845459[s]
# charles_montgomery_burns_5.jpg
# []
# Elapsed time = 0.7787384986877441[s]
# charles_montgomery_burns_6.jpg
# []
# Elapsed time = 0.9055793285369873[s]
# charles_montgomery_burns_7.jpg
# []
# Elapsed time = 0.8364579677581787[s]
# charles_montgomery_burns_8.jpg
# []
# Elapsed time = 0.8368270397186279[s]
# charles_montgomery_burns_9.jpg
# []
# Elapsed time = 0.8148915767669678[s]
# chief_wiggum_0.jpg
# [('chief_wiggum', 73.84520769119263)]
# Elapsed time = 0.778012752532959[s]
# chief_wiggum_1.jpg
# []
# Elapsed time = 0.7755846977233887[s]
# chief_wiggum_10.jpg
# []
# Elapsed time = 0.812847375869751[s]
# chief_wiggum_11.jpg
# [('chief_wiggum', 65.69516658782959)]
# Elapsed time = 0.7978618144989014[s]
# chief_wiggum_12.jpg
# [('chief_wiggum', 64.23566341400146)]
# Elapsed time = 0.8574025630950928[s]
# chief_wiggum_13.jpg
# []
# Elapsed time = 0.8190195560455322[s]
# chief_wiggum_14.jpg
# [('krusty_the_clown', 59.24541354179382)]
# Elapsed time = 0.8207933902740479[s]
# chief_wiggum_15.jpg
# [('krusty_the_clown', 57.952308654785156), ('chief_wiggum', 55.704498291015625)]
# Elapsed time = 0.8766558170318604[s]
# chief_wiggum_16.jpg
# []
# Elapsed time = 0.8497285842895508[s]
# chief_wiggum_17.jpg
# [('chief_wiggum', 57.73181915283203), ('marge_simpson', 67.23472476005554)]
# Elapsed time = 0.7928810119628906[s]
# chief_wiggum_18.jpg
# [('marge_simpson', 95.38445472717285), ('chief_wiggum', 55.2759051322937)]
# Elapsed time = 0.8208072185516357[s]
# chief_wiggum_19.jpg
# [('chief_wiggum', 62.708789110183716)]
# Elapsed time = 0.8228006362915039[s]
# chief_wiggum_2.jpg
# []
# Elapsed time = 0.7470016479492188[s]
# chief_wiggum_20.jpg
# [('chief_wiggum', 59.275615215301514), ('marge_simpson', 72.90599942207336)]
# Elapsed time = 0.7919127941131592[s]
# chief_wiggum_21.jpg
# []
# Elapsed time = 0.7798900604248047[s]
# chief_wiggum_22.jpg
# [('chief_wiggum', 65.22582769393921), ('marge_simpson', 82.51320123672485)]
# Elapsed time = 0.8128273487091064[s]
# chief_wiggum_23.jpg
# []
# Elapsed time = 0.7888906002044678[s]
# chief_wiggum_24.jpg
# []
# Elapsed time = 0.790886402130127[s]
# chief_wiggum_25.jpg
# []
# Elapsed time = 0.7509946823120117[s]
# chief_wiggum_26.jpg
# []
# Elapsed time = 0.8370199203491211[s]
# chief_wiggum_27.jpg
# [('chief_wiggum', 55.75363039970398)]
# Elapsed time = 0.8217015266418457[s]
# chief_wiggum_28.jpg
# []
# Elapsed time = 0.8836376667022705[s]
# chief_wiggum_29.jpg
# [('chief_wiggum', 60.29564142227173)]
# Elapsed time = 0.797870397567749[s]
# chief_wiggum_3.jpg
# []
# Elapsed time = 0.9033083915710449[s]
# chief_wiggum_30.jpg
# [('chief_wiggum', 66.83074831962585)]
# Elapsed time = 0.869673490524292[s]
# chief_wiggum_31.jpg
# []
# Elapsed time = 0.8327596187591553[s]
# chief_wiggum_32.jpg
# []
# Elapsed time = 0.9285178184509277[s]
# chief_wiggum_33.jpg
# [('chief_wiggum', 61.328673362731934)]
# Elapsed time = 0.8409645557403564[s]
# chief_wiggum_34.jpg
# []
# Elapsed time = 0.8100013732910156[s]
# chief_wiggum_35.jpg
# [('marge_simpson', 79.01454567909241)]
# Elapsed time = 0.8599228858947754[s]
# chief_wiggum_36.jpg
# []
# Elapsed time = 0.7823681831359863[s]
# chief_wiggum_37.jpg
# []
# Elapsed time = 0.7746696472167969[s]
# chief_wiggum_38.jpg
# [('chief_wiggum', 63.616007566452026)]
# Elapsed time = 0.8043739795684814[s]
# chief_wiggum_39.jpg
# []
# Elapsed time = 0.7495014667510986[s]
# chief_wiggum_4.jpg
# []
# Elapsed time = 0.8286924362182617[s]
# chief_wiggum_40.jpg
# [('chief_wiggum', 59.17902588844299), ('krusty_the_clown', 56.62878155708313)]
# Elapsed time = 0.8444979190826416[s]
# chief_wiggum_41.jpg
# []
# Elapsed time = 0.7533237934112549[s]
# chief_wiggum_42.jpg
# []
# Elapsed time = 0.8520541191101074[s]
# chief_wiggum_43.jpg
# [('chief_wiggum', 68.60868334770203)]
# Elapsed time = 0.850167989730835[s]
# chief_wiggum_44.jpg
# [('chief_wiggum', 61.02284789085388)]
# Elapsed time = 0.8192005157470703[s]
# chief_wiggum_45.jpg
# []
# Elapsed time = 0.9235134124755859[s]
# chief_wiggum_46.jpg
# []
# Elapsed time = 0.8556113243103027[s]
# chief_wiggum_47.jpg
# [('chief_wiggum', 61.489707231521606)]
# Elapsed time = 0.8986034393310547[s]
# chief_wiggum_48.jpg
# []
# Elapsed time = 0.7919716835021973[s]
# chief_wiggum_49.jpg
# [('chief_wiggum', 55.897074937820435)]
# Elapsed time = 0.8876280784606934[s]
# chief_wiggum_5.jpg
# []
# Elapsed time = 0.8399248123168945[s]
# chief_wiggum_6.jpg
# []
# Elapsed time = 0.8737776279449463[s]
# chief_wiggum_7.jpg
# [('marge_simpson', 56.09212517738342)]
# Elapsed time = 0.7466037273406982[s]
# chief_wiggum_8.jpg
# []
# Elapsed time = 0.8355662822723389[s]
# chief_wiggum_9.jpg
# [('chief_wiggum', 59.17902588844299), ('krusty_the_clown', 56.62878155708313)]
# Elapsed time = 0.8552234172821045[s]
# comic_book_guy_0.jpg
# [('marge_simpson', 63.10107707977295)]
# Elapsed time = 0.841179370880127[s]
# comic_book_guy_1.jpg
# []
# Elapsed time = 0.9316673278808594[s]
# comic_book_guy_10.jpg
# []
# Elapsed time = 0.7590112686157227[s]
# comic_book_guy_11.jpg
# []
# Elapsed time = 0.8019633293151855[s]
# comic_book_guy_12.jpg
# []
# Elapsed time = 0.803408145904541[s]
# comic_book_guy_13.jpg
# [('krusty_the_clown', 57.713645696640015)]
# Elapsed time = 0.7671689987182617[s]
# comic_book_guy_14.jpg
# [('marge_simpson', 59.825003147125244)]
# Elapsed time = 0.826317310333252[s]
# comic_book_guy_15.jpg
# []
# Elapsed time = 0.8439419269561768[s]
# comic_book_guy_16.jpg
# []
# Elapsed time = 0.8135790824890137[s]
# comic_book_guy_17.jpg
# []
# Elapsed time = 0.8223812580108643[s]
# comic_book_guy_18.jpg
# []
# Elapsed time = 0.8457531929016113[s]
# comic_book_guy_19.jpg
# [('marge_simpson', 73.3113706111908)]
# Elapsed time = 0.8972301483154297[s]
# comic_book_guy_2.jpg
# []
# Elapsed time = 0.7645130157470703[s]
# comic_book_guy_20.jpg
# []
# Elapsed time = 0.7920160293579102[s]
# comic_book_guy_21.jpg
# []
# Elapsed time = 0.8629238605499268[s]
# comic_book_guy_22.jpg
# []
# Elapsed time = 0.8416564464569092[s]
# comic_book_guy_23.jpg
# []
# Elapsed time = 0.7675905227661133[s]
# comic_book_guy_24.jpg
# []
# Elapsed time = 0.8242967128753662[s]
# comic_book_guy_25.jpg
# [('chief_wiggum', 77.55209803581238)]
# Elapsed time = 0.8043594360351562[s]
# comic_book_guy_26.jpg
# []
# Elapsed time = 0.751882791519165[s]
# comic_book_guy_27.jpg
# []
# Elapsed time = 0.8097939491271973[s]
# comic_book_guy_28.jpg
# []
# Elapsed time = 0.8295924663543701[s]
# comic_book_guy_29.jpg
# [('marge_simpson', 75.1233458518982)]
# Elapsed time = 0.8800144195556641[s]
# comic_book_guy_3.jpg
# []
# Elapsed time = 0.9098618030548096[s]
# comic_book_guy_30.jpg
# []
# Elapsed time = 0.8295135498046875[s]
# comic_book_guy_31.jpg
# []
# Elapsed time = 0.9048230648040771[s]
# comic_book_guy_32.jpg
# [('marge_simpson', 68.32146048545837)]
# Elapsed time = 0.8007311820983887[s]
# comic_book_guy_33.jpg
# []
# Elapsed time = 0.8333113193511963[s]
# comic_book_guy_34.jpg
# []
# Elapsed time = 0.7731168270111084[s]
# comic_book_guy_36.jpg
# [('krusty_the_clown', 55.0401508808136)]
# Elapsed time = 0.8235971927642822[s]
# comic_book_guy_37.jpg
# []
# Elapsed time = 0.7937755584716797[s]
# comic_book_guy_38.jpg
# []
# Elapsed time = 0.8205773830413818[s]
# comic_book_guy_39.jpg
# []
# Elapsed time = 0.7642385959625244[s]
# comic_book_guy_4.jpg
# []
# Elapsed time = 0.8316211700439453[s]
# comic_book_guy_40.jpg
# [('marge_simpson', 74.72830414772034)]
# Elapsed time = 0.7950046062469482[s]
# comic_book_guy_41.jpg
# [('krusty_the_clown', 59.6683144569397)]
# Elapsed time = 0.905813455581665[s]
# comic_book_guy_42.jpg
# []
# Elapsed time = 0.9540276527404785[s]
# comic_book_guy_43.jpg
# []
# Elapsed time = 0.8035578727722168[s]
# comic_book_guy_44.jpg
# []
# Elapsed time = 0.7898902893066406[s]
# comic_book_guy_45.jpg
# []
# Elapsed time = 0.744215726852417[s]
# comic_book_guy_46.jpg
# [('chief_wiggum', 62.501370906829834)]
# Elapsed time = 0.7796916961669922[s]
# comic_book_guy_47.jpg
# [('marge_simpson', 72.09274768829346)]
# Elapsed time = 0.8749425411224365[s]
# comic_book_guy_48.jpg
# []
# Elapsed time = 0.826246976852417[s]
# comic_book_guy_49.jpg
# []
# Elapsed time = 0.7679030895233154[s]
# comic_book_guy_5.jpg
# [('marge_simpson', 93.44661235809326)]
# Elapsed time = 0.836700439453125[s]
# comic_book_guy_6.jpg
# []
# Elapsed time = 0.7784106731414795[s]
# comic_book_guy_7.jpg
# []
# Elapsed time = 0.7813682556152344[s]
# comic_book_guy_8.jpg
# []
# Elapsed time = 0.8970763683319092[s]
# comic_book_guy_9.jpg
# []
# Elapsed time = 0.8177337646484375[s]
# edna_krabappel_0.jpg
# []
# Elapsed time = 0.7387008666992188[s]
# edna_krabappel_1.jpg
# []
# Elapsed time = 0.8315019607543945[s]
# edna_krabappel_10.jpg
# []
# Elapsed time = 0.7638483047485352[s]
# edna_krabappel_11.jpg
# []
# Elapsed time = 0.86850905418396[s]
# edna_krabappel_12.jpg
# []
# Elapsed time = 0.8187181949615479[s]
# edna_krabappel_13.jpg
# []
# Elapsed time = 0.8832440376281738[s]
# edna_krabappel_14.jpg
# []
# Elapsed time = 0.742150068283081[s]
# edna_krabappel_15.jpg
# []
# Elapsed time = 0.8138470649719238[s]
# edna_krabappel_16.jpg
# []
# Elapsed time = 0.813136100769043[s]
# edna_krabappel_17.jpg
# []
# Elapsed time = 0.908271074295044[s]
# edna_krabappel_18.jpg
# []
# Elapsed time = 0.9772274494171143[s]
# edna_krabappel_19.jpg
# []
# Elapsed time = 0.8968193531036377[s]
# edna_krabappel_2.jpg
# []
# Elapsed time = 0.9177353382110596[s]
# edna_krabappel_20.jpg
# []
# Elapsed time = 0.8859086036682129[s]
# edna_krabappel_21.jpg
# []
# Elapsed time = 0.8596839904785156[s]
# edna_krabappel_22.jpg
# []
# Elapsed time = 0.8890347480773926[s]
# edna_krabappel_23.jpg
# []
# Elapsed time = 0.7590301036834717[s]
# edna_krabappel_24.jpg
# []
# Elapsed time = 0.8296995162963867[s]
# edna_krabappel_25.jpg
# []
# Elapsed time = 0.8676049709320068[s]
# edna_krabappel_26.jpg
# []
# Elapsed time = 0.8914444446563721[s]
# edna_krabappel_27.jpg
# [('krusty_the_clown', 58.37215185165405)]
# Elapsed time = 0.7781755924224854[s]
# edna_krabappel_28.jpg
# []
# Elapsed time = 0.821953296661377[s]
# edna_krabappel_29.jpg
# []
# Elapsed time = 0.809584379196167[s]
# edna_krabappel_3.jpg
# []
# Elapsed time = 0.7368428707122803[s]
# edna_krabappel_30.jpg
# []
# Elapsed time = 0.8101806640625[s]
# edna_krabappel_31.jpg
# []
# Elapsed time = 0.8609957695007324[s]
# edna_krabappel_32.jpg
# []
# Elapsed time = 0.8807327747344971[s]
# edna_krabappel_33.jpg
# []
# Elapsed time = 0.8347494602203369[s]
# edna_krabappel_34.jpg
# []
# Elapsed time = 0.749448299407959[s]
# edna_krabappel_35.jpg
# []
# Elapsed time = 1.0471370220184326[s]
# edna_krabappel_36.jpg
# [('krusty_the_clown', 57.24039673805237)]
# Elapsed time = 0.9160211086273193[s]
# edna_krabappel_37.jpg
# []
# Elapsed time = 1.0690486431121826[s]
# edna_krabappel_38.jpg
# []
# Elapsed time = 0.8157966136932373[s]
# edna_krabappel_39.jpg
# []
# Elapsed time = 0.789588451385498[s]
# edna_krabappel_4.jpg
# []
# Elapsed time = 0.7614078521728516[s]
# edna_krabappel_40.jpg
# []
# Elapsed time = 0.7589895725250244[s]
# edna_krabappel_41.jpg
# []
# Elapsed time = 0.7438075542449951[s]
# edna_krabappel_42.jpg
# []
# Elapsed time = 0.8132960796356201[s]
# edna_krabappel_43.jpg
# []
# Elapsed time = 0.8365726470947266[s]
# edna_krabappel_44.jpg
# []
# Elapsed time = 0.8306667804718018[s]
# edna_krabappel_45.jpg
# []
# Elapsed time = 0.8133299350738525[s]
# edna_krabappel_46.jpg
# []
# Elapsed time = 0.9106013774871826[s]
# edna_krabappel_47.jpg
# [('krusty_the_clown', 58.43085050582886)]
# Elapsed time = 0.8063139915466309[s]
# edna_krabappel_48.jpg
# []
# Elapsed time = 0.8863174915313721[s]
# edna_krabappel_49.jpg
# []
# Elapsed time = 0.7436938285827637[s]
# edna_krabappel_5.jpg
# []
# Elapsed time = 0.7779636383056641[s]
# edna_krabappel_6.jpg
# []
# Elapsed time = 0.8606650829315186[s]
# edna_krabappel_7.jpg
# []
# Elapsed time = 0.8485863208770752[s]
# edna_krabappel_8.jpg
# []
# Elapsed time = 0.8789141178131104[s]
# edna_krabappel_9.jpg
# [('krusty_the_clown', 58.2563042640686)]
# Elapsed time = 0.7862539291381836[s]
# homer_simpson_0.jpg
# []
# Elapsed time = 0.847048282623291[s]
# homer_simpson_1.jpg
# []
# Elapsed time = 0.8791475296020508[s]
# homer_simpson_10.jpg
# []
# Elapsed time = 0.9245059490203857[s]
# homer_simpson_11.jpg
# []
# Elapsed time = 0.8248608112335205[s]
# homer_simpson_12.jpg
# []
# Elapsed time = 0.8144478797912598[s]
# homer_simpson_13.jpg
# []
# Elapsed time = 0.7950868606567383[s]
# homer_simpson_14.jpg
# []
# Elapsed time = 0.8050951957702637[s]
# homer_simpson_15.jpg
# []
# Elapsed time = 0.8009500503540039[s]
# homer_simpson_16.jpg
# [('marge_simpson', 67.89050102233887)]
# Elapsed time = 0.7996747493743896[s]
# homer_simpson_17.jpg
# []
# Elapsed time = 0.7947654724121094[s]
# homer_simpson_18.jpg
# []
# Elapsed time = 0.890387773513794[s]
# homer_simpson_19.jpg
# []
# Elapsed time = 0.7654633522033691[s]
# homer_simpson_2.jpg
# []
# Elapsed time = 0.8886444568634033[s]
# homer_simpson_20.jpg
# []
# Elapsed time = 0.7838754653930664[s]
# homer_simpson_21.jpg
# []
# Elapsed time = 0.8589217662811279[s]
# homer_simpson_22.jpg
# []
# Elapsed time = 0.8168208599090576[s]
# homer_simpson_23.jpg
# []
# Elapsed time = 0.8312418460845947[s]
# homer_simpson_24.jpg
# []
# Elapsed time = 0.8298072814941406[s]
# homer_simpson_25.jpg
# [('marge_simpson', 73.56295585632324)]
# Elapsed time = 0.8809959888458252[s]
# homer_simpson_26.jpg
# [('chief_wiggum', 81.23835325241089)]
# Elapsed time = 0.8439843654632568[s]
# homer_simpson_27.jpg
# []
# Elapsed time = 0.9167931079864502[s]
# homer_simpson_28.jpg
# []
# Elapsed time = 0.8566691875457764[s]
# homer_simpson_29.jpg
# []
# Elapsed time = 0.8141558170318604[s]
# homer_simpson_3.jpg
# []
# Elapsed time = 0.8250997066497803[s]
# homer_simpson_30.jpg
# []
# Elapsed time = 0.8182480335235596[s]
# homer_simpson_31.jpg
# []
# Elapsed time = 0.8746719360351562[s]
# homer_simpson_32.jpg
# []
# Elapsed time = 0.8442933559417725[s]
# homer_simpson_33.jpg
# []
# Elapsed time = 0.8021531105041504[s]
# homer_simpson_34.jpg
# []
# Elapsed time = 0.8501009941101074[s]
# homer_simpson_35.jpg
# [('marge_simpson', 72.45829701423645)]
# Elapsed time = 0.8495559692382812[s]
# homer_simpson_36.jpg
# []
# Elapsed time = 0.8113000392913818[s]
# homer_simpson_37.jpg
# []
# Elapsed time = 0.842531681060791[s]
# homer_simpson_38.jpg
# [('krusty_the_clown', 58.060914278030396)]
# Elapsed time = 0.862440824508667[s]
# homer_simpson_39.jpg
# []
# Elapsed time = 0.8143389225006104[s]
# homer_simpson_4.jpg
# []
# Elapsed time = 0.8080902099609375[s]
# homer_simpson_40.jpg
# []
# Elapsed time = 0.8726670742034912[s]
# homer_simpson_41.jpg
# []
# Elapsed time = 0.8297834396362305[s]
# homer_simpson_42.jpg
# []
# Elapsed time = 0.8002266883850098[s]
# homer_simpson_43.jpg
# []
# Elapsed time = 0.8584036827087402[s]
# homer_simpson_44.jpg
# []
# Elapsed time = 0.8085010051727295[s]
# homer_simpson_45.jpg
# []
# Elapsed time = 0.8760058879852295[s]
# homer_simpson_46.jpg
# []
# Elapsed time = 0.7886803150177002[s]
# homer_simpson_47.jpg
# []
# Elapsed time = 0.8366963863372803[s]
# homer_simpson_48.jpg
# []
# Elapsed time = 0.8370749950408936[s]
# homer_simpson_49.jpg
# [('krusty_the_clown', 63.06045055389404)]
# Elapsed time = 0.7986226081848145[s]
# homer_simpson_5.jpg
# [('marge_simpson', 61.60238981246948)]
# Elapsed time = 0.8444271087646484[s]
# homer_simpson_6.jpg
# []
# Elapsed time = 0.7719089984893799[s]
# homer_simpson_7.jpg
# []
# Elapsed time = 0.8913857936859131[s]
# homer_simpson_8.jpg
# []
# Elapsed time = 0.8287675380706787[s]
# homer_simpson_9.jpg
# [('marge_simpson', 66.71105623245239)]
# Elapsed time = 0.7998037338256836[s]
# kent_brockman_0.jpg
# []
# Elapsed time = 0.8525564670562744[s]
# kent_brockman_1.jpg
# []
# Elapsed time = 0.7704741954803467[s]
# kent_brockman_10.jpg
# []
# Elapsed time = 0.8077437877655029[s]
# kent_brockman_11.jpg
# [('marge_simpson', 56.131935119628906)]
# Elapsed time = 0.8332338333129883[s]
# kent_brockman_12.jpg
# [('marge_simpson', 65.7935380935669)]
# Elapsed time = 0.779470682144165[s]
# kent_brockman_13.jpg
# [('krusty_the_clown', 60.870206356048584)]
# Elapsed time = 0.8066534996032715[s]
# kent_brockman_14.jpg
# []
# Elapsed time = 0.8070805072784424[s]
# kent_brockman_15.jpg
# []
# Elapsed time = 0.8292975425720215[s]
# kent_brockman_16.jpg
# []
# Elapsed time = 0.7865090370178223[s]
# kent_brockman_17.jpg
# []
# Elapsed time = 0.8514378070831299[s]
# kent_brockman_18.jpg
# []
# Elapsed time = 0.8584318161010742[s]
# kent_brockman_19.jpg
# []
# Elapsed time = 0.8417494297027588[s]
# kent_brockman_2.jpg
# [('marge_simpson', 60.9438419342041)]
# Elapsed time = 0.8537189960479736[s]
# kent_brockman_20.jpg
# [('marge_simpson', 55.03717660903931)]
# Elapsed time = 0.8198089599609375[s]
# kent_brockman_21.jpg
# [('krusty_the_clown', 64.8245096206665)]
# Elapsed time = 0.8700339794158936[s]
# kent_brockman_22.jpg
# []
# Elapsed time = 0.859889030456543[s]
# kent_brockman_23.jpg
# []
# Elapsed time = 0.8696742057800293[s]
# kent_brockman_24.jpg
# [('marge_simpson', 79.38675880432129)]
# Elapsed time = 0.8547165393829346[s]
# kent_brockman_25.jpg
# []
# Elapsed time = 0.8497047424316406[s]
# kent_brockman_26.jpg
# []
# Elapsed time = 1.2045166492462158[s]
# kent_brockman_27.jpg
# []
# Elapsed time = 0.8971583843231201[s]
# kent_brockman_28.jpg
# []
# Elapsed time = 0.847567081451416[s]
# kent_brockman_29.jpg
# []
# Elapsed time = 0.7859089374542236[s]
# kent_brockman_3.jpg
# [('krusty_the_clown', 59.26421284675598)]
# Elapsed time = 1.04488205909729[s]
# kent_brockman_30.jpg
# [('marge_simpson', 63.38760852813721)]
# Elapsed time = 0.8369176387786865[s]
# kent_brockman_31.jpg
# []
# Elapsed time = 0.877943754196167[s]
# kent_brockman_32.jpg
# [('marge_simpson', 60.9438419342041)]
# Elapsed time = 0.8516747951507568[s]
# kent_brockman_33.jpg
# []
# Elapsed time = 0.8162765502929688[s]
# kent_brockman_34.jpg
# []
# Elapsed time = 0.8108069896697998[s]
# kent_brockman_35.jpg
# [('marge_simpson', 62.782055139541626)]
# Elapsed time = 0.8417198657989502[s]
# kent_brockman_36.jpg
# [('krusty_the_clown', 57.008373737335205)]
# Elapsed time = 0.7892019748687744[s]
# kent_brockman_37.jpg
# []
# Elapsed time = 0.8113565444946289[s]
# kent_brockman_38.jpg
# []
# Elapsed time = 0.801224946975708[s]
# kent_brockman_39.jpg
# []
# Elapsed time = 0.862746000289917[s]
# kent_brockman_4.jpg
# []
# Elapsed time = 0.8470628261566162[s]
# kent_brockman_40.jpg
# []
# Elapsed time = 0.8536419868469238[s]
# kent_brockman_41.jpg
# []
# Elapsed time = 0.8655281066894531[s]
# kent_brockman_42.jpg
# []
# Elapsed time = 0.8075082302093506[s]
# kent_brockman_43.jpg
# []
# Elapsed time = 0.8696489334106445[s]
# kent_brockman_44.jpg
# []
# Elapsed time = 0.7829408645629883[s]
# kent_brockman_45.jpg
# [('marge_simpson', 56.131935119628906)]
# Elapsed time = 0.8430478572845459[s]
# kent_brockman_46.jpg
# []
# Elapsed time = 0.8293256759643555[s]
# kent_brockman_47.jpg
# []
# Elapsed time = 0.8287429809570312[s]
# kent_brockman_48.jpg
# []
# Elapsed time = 0.8020062446594238[s]
# kent_brockman_49.jpg
# []
# Elapsed time = 0.7950258255004883[s]
# kent_brockman_5.jpg
# []
# Elapsed time = 0.8472959995269775[s]
# kent_brockman_6.jpg
# []
# Elapsed time = 0.8449981212615967[s]
# kent_brockman_7.jpg
# [('marge_simpson', 61.11190915107727)]
# Elapsed time = 0.8139157295227051[s]
# kent_brockman_8.jpg
# []
# Elapsed time = 0.7597601413726807[s]
# kent_brockman_9.jpg
# []
# Elapsed time = 0.7814493179321289[s]
# krusty_the_clown_0.jpg
# []
# Elapsed time = 0.8085892200469971[s]
# krusty_the_clown_1.jpg
# [('chief_wiggum', 73.08486700057983)]
# Elapsed time = 0.8436822891235352[s]
# krusty_the_clown_10.jpg
# []
# Elapsed time = 0.8345706462860107[s]
# krusty_the_clown_11.jpg
# [('krusty_the_clown', 64.19637203216553)]
# Elapsed time = 0.7710111141204834[s]
# krusty_the_clown_12.jpg
# []
# Elapsed time = 0.8610899448394775[s]
# krusty_the_clown_13.jpg
# []
# Elapsed time = 0.77852463722229[s]
# krusty_the_clown_14.jpg
# [('krusty_the_clown', 60.631585121154785)]
# Elapsed time = 0.8001260757446289[s]
# krusty_the_clown_15.jpg
# []
# Elapsed time = 0.7982776165008545[s]
# krusty_the_clown_16.jpg
# [('marge_simpson', 69.46995258331299)]
# Elapsed time = 0.8086092472076416[s]
# krusty_the_clown_17.jpg
# []
# Elapsed time = 0.7926974296569824[s]
# krusty_the_clown_18.jpg
# [('marge_simpson', 64.9532675743103)]
# Elapsed time = 0.8007540702819824[s]
# krusty_the_clown_19.jpg
# [('krusty_the_clown', 59.7348690032959)]
# Elapsed time = 0.8399577140808105[s]
# krusty_the_clown_2.jpg
# []
# Elapsed time = 0.8364400863647461[s]
# krusty_the_clown_20.jpg
# []
# Elapsed time = 0.7908456325531006[s]
# krusty_the_clown_21.jpg
# []
# Elapsed time = 0.7941699028015137[s]
# krusty_the_clown_22.jpg
# []
# Elapsed time = 0.7837839126586914[s]
# krusty_the_clown_23.jpg
# []
# Elapsed time = 0.8461098670959473[s]
# krusty_the_clown_24.jpg
# [('krusty_the_clown', 55.73660135269165)]
# Elapsed time = 0.7342252731323242[s]
# krusty_the_clown_25.jpg
# []
# Elapsed time = 0.8261454105377197[s]
# krusty_the_clown_26.jpg
# []
# Elapsed time = 0.8199548721313477[s]
# krusty_the_clown_27.jpg
# []
# Elapsed time = 0.8105447292327881[s]
# krusty_the_clown_28.jpg
# []
# Elapsed time = 0.8181498050689697[s]
# krusty_the_clown_29.jpg
# []
# Elapsed time = 0.8323452472686768[s]
# krusty_the_clown_3.jpg
# []
# Elapsed time = 0.8561506271362305[s]
# krusty_the_clown_30.jpg
# []
# Elapsed time = 0.7811660766601562[s]
# krusty_the_clown_31.jpg
# []
# Elapsed time = 0.835841178894043[s]
# krusty_the_clown_32.jpg
# []
# Elapsed time = 0.7826080322265625[s]
# krusty_the_clown_33.jpg
# []
# Elapsed time = 0.7695903778076172[s]
# krusty_the_clown_34.jpg
# [('krusty_the_clown', 59.16762351989746)]
# Elapsed time = 0.867283821105957[s]
# krusty_the_clown_35.jpg
# []
# Elapsed time = 0.7840268611907959[s]
# krusty_the_clown_36.jpg
# []
# Elapsed time = 0.8286051750183105[s]
# krusty_the_clown_37.jpg
# []
# Elapsed time = 0.8690669536590576[s]
# krusty_the_clown_38.jpg
# []
# Elapsed time = 0.7986845970153809[s]
# krusty_the_clown_39.jpg
# []
# Elapsed time = 0.8903343677520752[s]
# krusty_the_clown_4.jpg
# []
# Elapsed time = 0.8139047622680664[s]
# krusty_the_clown_40.jpg
# []
# Elapsed time = 0.8874213695526123[s]
# krusty_the_clown_41.jpg
# [('marge_simpson', 66.95911884307861)]
# Elapsed time = 0.8213493824005127[s]
# krusty_the_clown_42.jpg
# []
# Elapsed time = 0.822345495223999[s]
# krusty_the_clown_43.jpg
# []
# Elapsed time = 0.7628293037414551[s]
# krusty_the_clown_44.jpg
# []
# Elapsed time = 0.7754733562469482[s]
# krusty_the_clown_45.jpg
# []
# Elapsed time = 0.7992403507232666[s]
# krusty_the_clown_46.jpg
# []
# Elapsed time = 0.8132979869842529[s]
# krusty_the_clown_47.jpg
# []
# Elapsed time = 0.8002581596374512[s]
# krusty_the_clown_48.jpg
# []
# Elapsed time = 0.8626477718353271[s]
# krusty_the_clown_49.jpg
# []
# Elapsed time = 0.8586933612823486[s]
# krusty_the_clown_5.jpg
# []
# Elapsed time = 0.8171639442443848[s]
# krusty_the_clown_6.jpg
# []
# Elapsed time = 0.8274412155151367[s]
# krusty_the_clown_7.jpg
# []
# Elapsed time = 0.8524694442749023[s]
# krusty_the_clown_8.jpg
# []
# Elapsed time = 0.8403174877166748[s]
# krusty_the_clown_9.jpg
# [('krusty_the_clown', 58.729785680770874)]
# Elapsed time = 0.8925273418426514[s]
# lenny_leonard_0.jpg
# []
# Elapsed time = 0.8675498962402344[s]
# lenny_leonard_1.jpg
# []
# Elapsed time = 0.826716423034668[s]
# lenny_leonard_10.jpg
# [('marge_simpson', 74.30909276008606)]
# Elapsed time = 0.8174870014190674[s]
# lenny_leonard_11.jpg
# []
# Elapsed time = 0.8498373031616211[s]
# lenny_leonard_12.jpg
# []
# Elapsed time = 0.8628826141357422[s]
# lenny_leonard_13.jpg
# [('marge_simpson', 67.19240546226501)]
# Elapsed time = 0.8480470180511475[s]
# lenny_leonard_14.jpg
# []
# Elapsed time = 0.9045658111572266[s]
# lenny_leonard_15.jpg
# []
# Elapsed time = 0.8684597015380859[s]
# lenny_leonard_16.jpg
# []
# Elapsed time = 0.8915948867797852[s]
# lenny_leonard_17.jpg
# []
# Elapsed time = 0.7971310615539551[s]
# lenny_leonard_18.jpg
# []
# Elapsed time = 0.7909204959869385[s]
# lenny_leonard_19.jpg
# []
# Elapsed time = 0.8320200443267822[s]
# lenny_leonard_2.jpg
# [('chief_wiggum', 65.18515348434448)]
# Elapsed time = 0.8177883625030518[s]
# lenny_leonard_20.jpg
# []
# Elapsed time = 0.8711681365966797[s]
# lenny_leonard_21.jpg
# []
# Elapsed time = 0.8390250205993652[s]
# lenny_leonard_22.jpg
# []
# Elapsed time = 0.8198060989379883[s]
# lenny_leonard_23.jpg
# [('marge_simpson', 71.26507759094238)]
# Elapsed time = 0.8395755290985107[s]
# lenny_leonard_24.jpg
# []
# Elapsed time = 0.7298827171325684[s]
# lenny_leonard_25.jpg
# []
# Elapsed time = 0.8327529430389404[s]
# lenny_leonard_26.jpg
# [('marge_simpson', 60.9083354473114)]
# Elapsed time = 0.8210592269897461[s]
# lenny_leonard_27.jpg
# []
# Elapsed time = 0.8192496299743652[s]
# lenny_leonard_28.jpg
# []
# Elapsed time = 0.7743191719055176[s]
# lenny_leonard_29.jpg
# []
# Elapsed time = 0.8275604248046875[s]
# lenny_leonard_3.jpg
# []
# Elapsed time = 0.7813129425048828[s]
# lenny_leonard_30.jpg
# []
# Elapsed time = 0.8200616836547852[s]
# lenny_leonard_31.jpg
# []
# Elapsed time = 1.0688591003417969[s]
# lenny_leonard_32.jpg
# []
# Elapsed time = 0.8055956363677979[s]
# lenny_leonard_33.jpg
# []
# Elapsed time = 0.8329801559448242[s]
# lenny_leonard_34.jpg
# []
# Elapsed time = 0.8477652072906494[s]
# lenny_leonard_35.jpg
# []
# Elapsed time = 0.7776858806610107[s]
# lenny_leonard_36.jpg
# []
# Elapsed time = 0.789757251739502[s]
# lenny_leonard_37.jpg
# []
# Elapsed time = 0.8275372982025146[s]
# lenny_leonard_38.jpg
# []
# Elapsed time = 0.799903154373169[s]
# lenny_leonard_39.jpg
# []
# Elapsed time = 0.7670576572418213[s]
# lenny_leonard_4.jpg
# []
# Elapsed time = 0.8678221702575684[s]
# lenny_leonard_40.jpg
# []
# Elapsed time = 0.8255646228790283[s]
# lenny_leonard_41.jpg
# []
# Elapsed time = 0.775825023651123[s]
# lenny_leonard_42.jpg
# []
# Elapsed time = 0.7765085697174072[s]
# lenny_leonard_43.jpg
# []
# Elapsed time = 0.8141000270843506[s]
# lenny_leonard_44.jpg
# []
# Elapsed time = 0.8010942935943604[s]
# lenny_leonard_45.jpg
# []
# Elapsed time = 0.7957131862640381[s]
# lenny_leonard_46.jpg
# []
# Elapsed time = 0.814084529876709[s]
# lenny_leonard_47.jpg
# []
# Elapsed time = 0.7857060432434082[s]
# lenny_leonard_48.jpg
# []
# Elapsed time = 0.8294811248779297[s]
# lenny_leonard_49.jpg
# []
# Elapsed time = 0.8363120555877686[s]
# lenny_leonard_5.jpg
# []
# Elapsed time = 0.8199982643127441[s]
# lenny_leonard_6.jpg
# []
# Elapsed time = 1.6815598011016846[s]
# lenny_leonard_7.jpg
# []
# Elapsed time = 0.759568452835083[s]
# lenny_leonard_8.jpg
# [('marge_simpson', 71.26507759094238)]
# Elapsed time = 0.8258121013641357[s]
# lenny_leonard_9.jpg
# []
# Elapsed time = 0.8828163146972656[s]
# lisa_simpson_0.jpg
# []
# Elapsed time = 0.7491250038146973[s]
# lisa_simpson_1.jpg
# [('lisa_simpson', 61.67638897895813)]
# Elapsed time = 0.8004095554351807[s]
# lisa_simpson_10.jpg
# []
# Elapsed time = 0.8039791584014893[s]
# lisa_simpson_11.jpg
# []
# Elapsed time = 0.8153033256530762[s]
# lisa_simpson_12.jpg
# []
# Elapsed time = 0.8662383556365967[s]
# lisa_simpson_13.jpg
# []
# Elapsed time = 0.8485207557678223[s]
# lisa_simpson_14.jpg
# []
# Elapsed time = 0.8326969146728516[s]
# lisa_simpson_15.jpg
# []
# Elapsed time = 0.8236968517303467[s]
# lisa_simpson_16.jpg
# []
# Elapsed time = 0.7969589233398438[s]
# lisa_simpson_17.jpg
# []
# Elapsed time = 0.8121285438537598[s]
# lisa_simpson_18.jpg
# []
# Elapsed time = 0.797271728515625[s]
# lisa_simpson_19.jpg
# []
# Elapsed time = 0.8508334159851074[s]
# lisa_simpson_2.jpg
# []
# Elapsed time = 0.8367493152618408[s]
# lisa_simpson_20.jpg
# [('marge_simpson', 71.2993323802948)]
# Elapsed time = 0.7949333190917969[s]
# lisa_simpson_21.jpg
# []
# Elapsed time = 0.8169105052947998[s]
# lisa_simpson_22.jpg
# []
# Elapsed time = 0.7346141338348389[s]
# lisa_simpson_23.jpg
# []
# Elapsed time = 0.7942609786987305[s]
# lisa_simpson_24.jpg
# []
# Elapsed time = 0.7742841243743896[s]
# lisa_simpson_25.jpg
# []
# Elapsed time = 0.7745842933654785[s]
# lisa_simpson_26.jpg
# []
# Elapsed time = 0.7968475818634033[s]
# lisa_simpson_27.jpg
# []
# Elapsed time = 0.8125619888305664[s]
# lisa_simpson_28.jpg
# []
# Elapsed time = 0.8010730743408203[s]
# lisa_simpson_29.jpg
# []
# Elapsed time = 0.8220069408416748[s]
# lisa_simpson_3.jpg
# []
# Elapsed time = 0.8299951553344727[s]
# lisa_simpson_30.jpg
# []
# Elapsed time = 0.8602244853973389[s]
# lisa_simpson_31.jpg
# []
# Elapsed time = 0.8780758380889893[s]
# lisa_simpson_32.jpg
# [('krusty_the_clown', 63.808971643447876)]
# Elapsed time = 0.8216619491577148[s]
# lisa_simpson_33.jpg
# []
# Elapsed time = 0.8281679153442383[s]
# lisa_simpson_34.jpg
# [('lisa_simpson', 58.24355483055115), ('marge_simpson', 59.656381607055664)]
# Elapsed time = 0.826458215713501[s]
# lisa_simpson_35.jpg
# []
# Elapsed time = 0.8296349048614502[s]
# lisa_simpson_36.jpg
# []
# Elapsed time = 0.7991693019866943[s]
# lisa_simpson_37.jpg
# []
# Elapsed time = 0.8531496524810791[s]
# lisa_simpson_38.jpg
# [('lisa_simpson', 60.42928099632263)]
# Elapsed time = 0.8163788318634033[s]
# lisa_simpson_39.jpg
# []
# Elapsed time = 0.7714560031890869[s]
# lisa_simpson_4.jpg
# []
# Elapsed time = 0.8352229595184326[s]
# lisa_simpson_40.jpg
# []
# Elapsed time = 0.8161141872406006[s]
# lisa_simpson_41.jpg
# [('marge_simpson', 61.621421575546265)]
# Elapsed time = 0.8327987194061279[s]
# lisa_simpson_42.jpg
# []
# Elapsed time = 0.824244499206543[s]
# lisa_simpson_43.jpg
# []
# Elapsed time = 0.8442673683166504[s]
# lisa_simpson_44.jpg
# []
# Elapsed time = 0.825005292892456[s]
# lisa_simpson_45.jpg
# []
# Elapsed time = 0.8262743949890137[s]
# lisa_simpson_46.jpg
# []
# Elapsed time = 0.7960631847381592[s]
# lisa_simpson_47.jpg
# [('krusty_the_clown', 56.09458684921265)]
# Elapsed time = 0.8350238800048828[s]
# lisa_simpson_48.jpg
# []
# Elapsed time = 0.8135135173797607[s]
# lisa_simpson_49.jpg
# []
# Elapsed time = 0.805182933807373[s]
# lisa_simpson_5.jpg
# [('lisa_simpson', 55.03438115119934), ('krusty_the_clown', 59.288257360458374)]
# Elapsed time = 0.7194230556488037[s]
# lisa_simpson_6.jpg
# [('marge_simpson', 72.42034673690796)]
# Elapsed time = 0.8367013931274414[s]
# lisa_simpson_7.jpg
# []
# Elapsed time = 0.8454444408416748[s]
# lisa_simpson_8.jpg
# []
# Elapsed time = 0.86580491065979[s]
# lisa_simpson_9.jpg
# []
# Elapsed time = 0.8226721286773682[s]
# marge_simpson_0.jpg
# [('marge_simpson', 90.49792885780334)]
# Elapsed time = 0.8007664680480957[s]
# marge_simpson_1.jpg
# [('marge_simpson', 85.28919219970703)]
# Elapsed time = 0.8437917232513428[s]
# marge_simpson_10.jpg
# [('marge_simpson', 91.39631390571594)]
# Elapsed time = 0.7945122718811035[s]
# marge_simpson_11.jpg
# [('marge_simpson', 69.54047679901123)]
# Elapsed time = 0.8442959785461426[s]
# marge_simpson_12.jpg
# [('marge_simpson', 79.42666411399841)]
# Elapsed time = 0.79740309715271[s]
# marge_simpson_13.jpg
# [('marge_simpson', 74.2036521434784)]
# Elapsed time = 0.8137149810791016[s]
# marge_simpson_14.jpg
# [('marge_simpson', 78.03708910942078)]
# Elapsed time = 0.8044312000274658[s]
# marge_simpson_15.jpg
# [('marge_simpson', 89.77935910224915)]
# Elapsed time = 0.8356726169586182[s]
# marge_simpson_16.jpg
# [('marge_simpson', 79.82460260391235)]
# Elapsed time = 0.7347962856292725[s]
# marge_simpson_17.jpg
# [('marge_simpson', 56.69068694114685)]
# Elapsed time = 0.7503435611724854[s]
# marge_simpson_18.jpg
# [('marge_simpson', 68.04879307746887)]
# Elapsed time = 0.7971749305725098[s]
# marge_simpson_19.jpg
# []
# Elapsed time = 0.827681303024292[s]
# marge_simpson_2.jpg
# [('marge_simpson', 89.97862339019775)]
# Elapsed time = 0.8294265270233154[s]
# marge_simpson_20.jpg
# [('marge_simpson', 91.83357954025269)]
# Elapsed time = 0.8286447525024414[s]
# marge_simpson_21.jpg
# [('marge_simpson', 90.62155485153198)]
# Elapsed time = 0.8443326950073242[s]
# marge_simpson_22.jpg
# [('marge_simpson', 79.3261706829071)]
# Elapsed time = 0.8284580707550049[s]
# marge_simpson_23.jpg
# [('marge_simpson', 70.11045217514038)]
# Elapsed time = 0.7958860397338867[s]
# marge_simpson_24.jpg
# [('marge_simpson', 76.34950280189514)]
# Elapsed time = 0.8261744976043701[s]
# marge_simpson_25.jpg
# [('marge_simpson', 89.32090997695923)]
# Elapsed time = 0.8627800941467285[s]
# marge_simpson_26.jpg
# [('marge_simpson', 73.90505075454712)]
# Elapsed time = 0.8365287780761719[s]
# marge_simpson_27.jpg
# [('marge_simpson', 76.84650421142578)]
# Elapsed time = 0.8220033645629883[s]
# marge_simpson_28.jpg
# [('marge_simpson', 91.60047173500061)]
# Elapsed time = 0.8547639846801758[s]
# marge_simpson_29.jpg
# [('marge_simpson', 79.91090416908264)]
# Elapsed time = 0.8222715854644775[s]
# marge_simpson_3.jpg
# [('marge_simpson', 67.09817051887512)]
# Elapsed time = 0.8207643032073975[s]
# marge_simpson_30.jpg
# [('marge_simpson', 83.92663598060608)]
# Elapsed time = 0.7802896499633789[s]
# marge_simpson_31.jpg
# [('marge_simpson', 65.218186378479)]
# Elapsed time = 0.7814288139343262[s]
# marge_simpson_32.jpg
# [('marge_simpson', 89.41538333892822)]
# Elapsed time = 0.8445324897766113[s]
# marge_simpson_33.jpg
# [('marge_simpson', 61.34864091873169)]
# Elapsed time = 0.8043453693389893[s]
# marge_simpson_34.jpg
# [('marge_simpson', 59.41139459609985)]
# Elapsed time = 0.8123598098754883[s]
# marge_simpson_35.jpg
# []
# Elapsed time = 0.8411593437194824[s]
# marge_simpson_36.jpg
# [('marge_simpson', 57.50131607055664)]
# Elapsed time = 0.8051936626434326[s]
# marge_simpson_37.jpg
# [('marge_simpson', 90.95824956893921)]
# Elapsed time = 0.8284227848052979[s]
# marge_simpson_38.jpg
# []
# Elapsed time = 0.8131341934204102[s]
# marge_simpson_39.jpg
# [('marge_simpson', 78.06920409202576)]
# Elapsed time = 0.8808383941650391[s]
# marge_simpson_4.jpg
# [('marge_simpson', 67.2590434551239)]
# Elapsed time = 0.8295407295227051[s]
# marge_simpson_40.jpg
# [('marge_simpson', 75.85316896438599)]
# Elapsed time = 0.8312418460845947[s]
# marge_simpson_41.jpg
# [('marge_simpson', 59.26036238670349)]
# Elapsed time = 0.8079566955566406[s]
# marge_simpson_42.jpg
# [('marge_simpson', 82.63742923736572)]
# Elapsed time = 0.8436541557312012[s]
# marge_simpson_43.jpg
# [('marge_simpson', 62.98709511756897)]
# Elapsed time = 0.8172914981842041[s]
# marge_simpson_44.jpg
# [('marge_simpson', 64.25978541374207)]
# Elapsed time = 0.8049085140228271[s]
# marge_simpson_45.jpg
# [('marge_simpson', 85.0803017616272)]
# Elapsed time = 0.8440365791320801[s]
# marge_simpson_46.jpg
# [('marge_simpson', 85.42966842651367)]
# Elapsed time = 0.7973325252532959[s]
# marge_simpson_47.jpg
# [('marge_simpson', 86.24677658081055)]
# Elapsed time = 0.8158609867095947[s]
# marge_simpson_48.jpg
# []
# Elapsed time = 0.7846462726593018[s]
# marge_simpson_49.jpg
# [('marge_simpson', 77.05464363098145)]
# Elapsed time = 0.7582399845123291[s]
# marge_simpson_5.jpg
# [('marge_simpson', 92.74684190750122)]
# Elapsed time = 0.8126013278961182[s]
# marge_simpson_6.jpg
# [('marge_simpson', 95.36083936691284)]
# Elapsed time = 0.82065749168396[s]
# marge_simpson_7.jpg
# [('marge_simpson', 62.39049434661865)]
# Elapsed time = 0.8148791790008545[s]
# marge_simpson_8.jpg
# []
# Elapsed time = 0.8013300895690918[s]
# marge_simpson_9.jpg
# [('marge_simpson', 86.31464838981628)]
# Elapsed time = 0.8444008827209473[s]
# mayor_quimby_0.jpg
# [('marge_simpson', 64.3267571926117)]
# Elapsed time = 0.7897739410400391[s]
# mayor_quimby_1.jpg
# []
# Elapsed time = 0.7792584896087646[s]
# mayor_quimby_10.jpg
# []
# Elapsed time = 0.8288793563842773[s]
# mayor_quimby_11.jpg
# [('marge_simpson', 64.87719416618347)]
# Elapsed time = 0.8142695426940918[s]
# mayor_quimby_12.jpg
# []
# Elapsed time = 0.7715981006622314[s]
# mayor_quimby_13.jpg
# []
# Elapsed time = 0.8286278247833252[s]
# mayor_quimby_14.jpg
# []
# Elapsed time = 0.7957940101623535[s]
# mayor_quimby_15.jpg
# [('marge_simpson', 73.77886176109314)]
# Elapsed time = 0.8152923583984375[s]
# mayor_quimby_16.jpg
# []
# Elapsed time = 0.8163220882415771[s]
# mayor_quimby_17.jpg
# []
# Elapsed time = 0.8430955410003662[s]
# mayor_quimby_18.jpg
# []
# Elapsed time = 0.7729661464691162[s]
# mayor_quimby_19.jpg
# []
# Elapsed time = 0.7831785678863525[s]
# mayor_quimby_2.jpg
# []
# Elapsed time = 0.8115534782409668[s]
# mayor_quimby_20.jpg
# []
# ...
# []
# Elapsed time = 0.8200492858886719[s]
# moe_szyslak_12.jpg
# []
# Elapsed time = 0.7835171222686768[s]
# moe_szyslak_13.jpg
# []
# Elapsed time = 0.769927978515625[s]
# moe_szyslak_14.jpg
# []
# Elapsed time = 0.8763232231140137[s]
# moe_szyslak_15.jpg
# []
# Elapsed time = 0.8047363758087158[s]
# moe_szyslak_16.jpg
# []
# Elapsed time = 0.8126239776611328[s]
# moe_szyslak_17.jpg
# []
# Elapsed time = 0.7832317352294922[s]
# moe_szyslak_18.jpg
# []
# Elapsed time = 0.7831385135650635[s]
# moe_szyslak_19.jpg
# []
# Elapsed time = 0.8142995834350586[s]
# moe_szyslak_2.jpg
# []
# Elapsed time = 0.8553752899169922[s]
# moe_szyslak_20.jpg
# []
# Elapsed time = 0.824514627456665[s]
# moe_szyslak_21.jpg
# []
# Elapsed time = 0.8016831874847412[s]
# moe_szyslak_22.jpg
# []
# Elapsed time = 0.7813296318054199[s]
# moe_szyslak_23.jpg
# []
# Elapsed time = 1.0136239528656006[s]
# moe_szyslak_24.jpg
# []
# Elapsed time = 0.8322129249572754[s]
# moe_szyslak_25.jpg
# []
# Elapsed time = 0.8227124214172363[s]
# moe_szyslak_26.jpg
# []
# Elapsed time = 0.8595764636993408[s]
# moe_szyslak_27.jpg
# []
# Elapsed time = 0.8200726509094238[s]
# moe_szyslak_28.jpg
# []
# Elapsed time = 0.7473483085632324[s]
# moe_szyslak_29.jpg
# []
# Elapsed time = 0.8254871368408203[s]
# moe_szyslak_3.jpg
# []
# Elapsed time = 0.792769193649292[s]
# moe_szyslak_30.jpg
# []
# Elapsed time = 0.8296401500701904[s]
# moe_szyslak_31.jpg
# [('krusty_the_clown', 57.60691165924072)]
# Elapsed time = 0.7977044582366943[s]
# moe_szyslak_32.jpg
# [('marge_simpson', 85.7944905757904)]
# Elapsed time = 0.8134794235229492[s]
# moe_szyslak_33.jpg
# []
# Elapsed time = 0.7795665264129639[s]
# moe_szyslak_34.jpg
# []
# Elapsed time = 0.7512814998626709[s]
# moe_szyslak_35.jpg
# []
# Elapsed time = 0.811774730682373[s]
# moe_szyslak_36.jpg
# []
# Elapsed time = 0.7511928081512451[s]
# moe_szyslak_37.jpg
# []
# Elapsed time = 0.8453819751739502[s]
# moe_szyslak_38.jpg
# []
# Elapsed time = 0.8171632289886475[s]
# moe_szyslak_39.jpg
# []
# Elapsed time = 0.8124039173126221[s]
# moe_szyslak_4.jpg
# []
# Elapsed time = 0.8042986392974854[s]
# moe_szyslak_40.jpg
# [('marge_simpson', 63.550782203674316)]
# Elapsed time = 0.7519304752349854[s]
# moe_szyslak_41.jpg
# []
# Elapsed time = 0.7418289184570312[s]
# moe_szyslak_42.jpg
# []
# Elapsed time = 0.8179612159729004[s]
# moe_szyslak_43.jpg
# []
# Elapsed time = 0.8136031627655029[s]
# moe_szyslak_44.jpg
# []
# Elapsed time = 0.7825827598571777[s]
# moe_szyslak_45.jpg
# []
# Elapsed time = 0.7489442825317383[s]
# moe_szyslak_46.jpg
# []
# Elapsed time = 0.7855217456817627[s]
# moe_szyslak_47.jpg
# []
# Elapsed time = 0.7985749244689941[s]
# moe_szyslak_48.jpg
# []
# Elapsed time = 0.7445375919342041[s]
# moe_szyslak_49.jpg
# []
# Elapsed time = 0.7496659755706787[s]
# moe_szyslak_5.jpg
# []
# Elapsed time = 0.8221397399902344[s]
# moe_szyslak_6.jpg
# []
# Elapsed time = 0.7501637935638428[s]
# moe_szyslak_7.jpg
# []
# Elapsed time = 0.8333282470703125[s]
# moe_szyslak_8.jpg
# []
# Elapsed time = 0.7970354557037354[s]
# moe_szyslak_9.jpg
# []
# Elapsed time = 0.8747777938842773[s]
# ned_flanders_0.jpg
# []
# Elapsed time = 0.8125505447387695[s]
# ned_flanders_1.jpg
# []
# Elapsed time = 0.7888588905334473[s]
# ned_flanders_10.jpg
# []
# Elapsed time = 0.828432559967041[s]
# ned_flanders_11.jpg
# []
# Elapsed time = 0.8045291900634766[s]
# ned_flanders_12.jpg
# []
# Elapsed time = 0.7815663814544678[s]
# ned_flanders_13.jpg
# []
# Elapsed time = 0.7506203651428223[s]
# ned_flanders_14.jpg
# []
# Elapsed time = 0.840303897857666[s]
# ned_flanders_15.jpg
# []
# Elapsed time = 0.7852354049682617[s]
# ned_flanders_16.jpg
# [('krusty_the_clown', 56.43017888069153)]
# Elapsed time = 0.8273632526397705[s]
# ned_flanders_17.jpg
# []
# Elapsed time = 0.7668089866638184[s]
# ned_flanders_18.jpg
# []
# Elapsed time = 0.760570764541626[s]
# ned_flanders_19.jpg
# []
# Elapsed time = 0.8016223907470703[s]
# ned_flanders_2.jpg
# [('krusty_the_clown', 56.28913640975952)]
# Elapsed time = 0.730426549911499[s]
# ned_flanders_20.jpg
# []
# Elapsed time = 0.8277571201324463[s]
# ned_flanders_21.jpg
# []
# Elapsed time = 0.8124253749847412[s]
# ned_flanders_22.jpg
# []
# Elapsed time = 0.7629144191741943[s]
# ned_flanders_23.jpg
# []
# Elapsed time = 0.8273227214813232[s]
# ned_flanders_24.jpg
# []
# Elapsed time = 0.8497650623321533[s]
# ned_flanders_25.jpg
# []
# Elapsed time = 0.7474942207336426[s]
# ned_flanders_26.jpg
# []
# Elapsed time = 0.7901349067687988[s]
# ned_flanders_27.jpg
# [('krusty_the_clown', 55.52828311920166)]
# Elapsed time = 0.7628300189971924[s]
# ned_flanders_28.jpg
# []
# Elapsed time = 0.8078563213348389[s]
# ned_flanders_29.jpg
# [('marge_simpson', 85.0897490978241)]
# Elapsed time = 0.7814083099365234[s]
# ned_flanders_3.jpg
# []
# Elapsed time = 0.8264641761779785[s]
# ned_flanders_30.jpg
# []
# Elapsed time = 0.7344372272491455[s]
# ned_flanders_31.jpg
# [('marge_simpson', 63.146787881851196)]
# Elapsed time = 0.79323410987854[s]
# ned_flanders_32.jpg
# [('marge_simpson', 56.72062039375305)]
# Elapsed time = 0.8140420913696289[s]
# ned_flanders_33.jpg
# []
# Elapsed time = 0.8302440643310547[s]
# ned_flanders_34.jpg
# []
# Elapsed time = 0.7798535823822021[s]
# ned_flanders_35.jpg
# []
# Elapsed time = 0.7831861972808838[s]
# ned_flanders_36.jpg
# [('krusty_the_clown', 58.09374451637268)]
# Elapsed time = 0.7554700374603271[s]
# ned_flanders_37.jpg
# []
# Elapsed time = 0.9054348468780518[s]
# ned_flanders_38.jpg
# []
# Elapsed time = 0.7543556690216064[s]
# ned_flanders_39.jpg
# []
# Elapsed time = 0.8579261302947998[s]
# ned_flanders_4.jpg
# []
# Elapsed time = 0.820178747177124[s]
# ned_flanders_40.jpg
# []
# Elapsed time = 0.7417454719543457[s]
# ned_flanders_41.jpg
# []
# Elapsed time = 0.810875415802002[s]
# ned_flanders_42.jpg
# []
# Elapsed time = 0.8222506046295166[s]
# ned_flanders_43.jpg
# [('krusty_the_clown', 56.939905881881714)]
# Elapsed time = 0.8127365112304688[s]
# ned_flanders_44.jpg
# []
# Elapsed time = 0.7420275211334229[s]
# ned_flanders_46.jpg
# []
# Elapsed time = 0.8842787742614746[s]
# ned_flanders_47.jpg
# []
# Elapsed time = 0.7811391353607178[s]
# ned_flanders_48.jpg
# []
# Elapsed time = 0.7799599170684814[s]
# ned_flanders_49.jpg
# []
# Elapsed time = 0.7486207485198975[s]
# ned_flanders_5.jpg
# []
# Elapsed time = 0.7985420227050781[s]
# ned_flanders_6.jpg
# []
# Elapsed time = 0.8073625564575195[s]
# ned_flanders_7.jpg
# []
# Elapsed time = 0.7772462368011475[s]
# ned_flanders_8.jpg
# []
# Elapsed time = 0.812952995300293[s]
# ned_flanders_9.jpg
# []
# Elapsed time = 0.8189783096313477[s]
# nelson_muntz_0.jpg
# []
# Elapsed time = 0.8684451580047607[s]
# nelson_muntz_1.jpg
# [('chief_wiggum', 56.37639760971069), ('krusty_the_clown', 59.30531620979309)]
# Elapsed time = 0.735785961151123[s]
# nelson_muntz_10.jpg
# []
# Elapsed time = 0.772707462310791[s]
# nelson_muntz_11.jpg
# []
# Elapsed time = 0.73372483253479[s]
# nelson_muntz_12.jpg
# []
# Elapsed time = 0.7386324405670166[s]
# nelson_muntz_13.jpg
# []
# Elapsed time = 0.9003551006317139[s]
# nelson_muntz_14.jpg
# []
# Elapsed time = 0.8043396472930908[s]
# nelson_muntz_15.jpg
# []
# Elapsed time = 0.7342727184295654[s]
# nelson_muntz_16.jpg
# []
# Elapsed time = 0.7714900970458984[s]
# nelson_muntz_17.jpg
# []
# Elapsed time = 0.7486028671264648[s]
# nelson_muntz_18.jpg
# [('chief_wiggum', 56.81806802749634)]
# Elapsed time = 0.8126273155212402[s]
# nelson_muntz_19.jpg
# []
# Elapsed time = 0.7919588088989258[s]
# nelson_muntz_2.jpg
# [('marge_simpson', 57.06300139427185)]
# Elapsed time = 0.7874946594238281[s]
# nelson_muntz_20.jpg
# []
# Elapsed time = 0.7713463306427002[s]
# nelson_muntz_21.jpg
# []
# Elapsed time = 0.8365156650543213[s]
# nelson_muntz_22.jpg
# [('chief_wiggum', 58.97673964500427)]
# Elapsed time = 0.7528085708618164[s]
# nelson_muntz_23.jpg
# [('chief_wiggum', 66.372811794281)]
# Elapsed time = 0.745551586151123[s]
# nelson_muntz_24.jpg
# []
# Elapsed time = 0.8580935001373291[s]
# nelson_muntz_25.jpg
# []
# Elapsed time = 0.7817816734313965[s]
# nelson_muntz_26.jpg
# [('marge_simpson', 59.816139936447144)]
# Elapsed time = 0.796180009841919[s]
# nelson_muntz_27.jpg
# [('krusty_the_clown', 56.184643507003784)]
# Elapsed time = 0.8281798362731934[s]
# nelson_muntz_28.jpg
# []
# Elapsed time = 0.7777597904205322[s]
# nelson_muntz_29.jpg
# []
# Elapsed time = 0.7516171932220459[s]
# nelson_muntz_3.jpg
# []
# Elapsed time = 0.7499277591705322[s]
# nelson_muntz_30.jpg
# [('chief_wiggum', 67.95769333839417)]
# Elapsed time = 0.8052282333374023[s]
# nelson_muntz_31.jpg
# []
# Elapsed time = 0.8316426277160645[s]
# nelson_muntz_32.jpg
# []
# Elapsed time = 0.7858586311340332[s]
# nelson_muntz_33.jpg
# []
# Elapsed time = 0.8029279708862305[s]
# nelson_muntz_34.jpg
# []
# Elapsed time = 0.8510017395019531[s]
# nelson_muntz_35.jpg
# []
# Elapsed time = 0.8433589935302734[s]
# nelson_muntz_36.jpg
# []
# Elapsed time = 0.810896635055542[s]
# nelson_muntz_37.jpg
# []
# Elapsed time = 0.7910771369934082[s]
# nelson_muntz_38.jpg
# []
# Elapsed time = 0.7469003200531006[s]
# nelson_muntz_39.jpg
# [('chief_wiggum', 55.261361598968506)]
# Elapsed time = 0.828995943069458[s]
# nelson_muntz_4.jpg
# []
# Elapsed time = 0.7512311935424805[s]
# nelson_muntz_40.jpg
# []
# Elapsed time = 0.8196325302124023[s]
# nelson_muntz_41.jpg
# []
# Elapsed time = 0.8503994941711426[s]
# nelson_muntz_42.jpg
# []
# Elapsed time = 0.8780393600463867[s]
# nelson_muntz_43.jpg
# []
# Elapsed time = 0.7814314365386963[s]
# nelson_muntz_44.jpg
# []
# Elapsed time = 0.7820806503295898[s]
# nelson_muntz_45.jpg
# []
# Elapsed time = 0.7384357452392578[s]
# nelson_muntz_46.jpg
# []
# Elapsed time = 0.8176569938659668[s]
# nelson_muntz_47.jpg
# [('krusty_the_clown', 59.23088788986206)]
# Elapsed time = 0.7575573921203613[s]
# nelson_muntz_48.jpg
# [('chief_wiggum', 59.41176414489746)]
# Elapsed time = 0.7520155906677246[s]
# nelson_muntz_49.jpg
# []
# Elapsed time = 0.8899919986724854[s]
# nelson_muntz_5.jpg
# []
# Elapsed time = 0.7981860637664795[s]
# nelson_muntz_6.jpg
# []
# Elapsed time = 0.8116528987884521[s]
# nelson_muntz_7.jpg
# []
# Elapsed time = 0.7839138507843018[s]
# nelson_muntz_8.jpg
# []
# Elapsed time = 0.7965824604034424[s]
# nelson_muntz_9.jpg
# []
# Elapsed time = 0.7506704330444336[s]
# principal_skinner_0.jpg
# []
# Elapsed time = 0.8734290599822998[s]
# principal_skinner_1.jpg
# [('marge_simpson', 71.9936728477478)]
# Elapsed time = 0.807654857635498[s]
# principal_skinner_10.jpg
# []
# Elapsed time = 0.820512056350708[s]
# principal_skinner_11.jpg
# []
# Elapsed time = 0.8438329696655273[s]
# principal_skinner_12.jpg
# [('krusty_the_clown', 61.28688454627991)]
# Elapsed time = 0.8290948867797852[s]
# principal_skinner_13.jpg
# [('marge_simpson', 62.68436312675476)]
# Elapsed time = 0.8129322528839111[s]
# principal_skinner_14.jpg
# []
# Elapsed time = 0.8228268623352051[s]
# principal_skinner_15.jpg
# [('marge_simpson', 56.1711311340332)]
# Elapsed time = 0.7796876430511475[s]
# principal_skinner_16.jpg
# [('marge_simpson', 57.037895917892456)]
# Elapsed time = 0.8093664646148682[s]
# principal_skinner_17.jpg
# [('marge_simpson', 79.64333891868591)]
# Elapsed time = 0.7959201335906982[s]
# principal_skinner_18.jpg
# []
# Elapsed time = 0.8414368629455566[s]
# principal_skinner_19.jpg
# []
# Elapsed time = 0.7896699905395508[s]
# principal_skinner_2.jpg
# []
# Elapsed time = 0.8079555034637451[s]
# principal_skinner_20.jpg
# []
# Elapsed time = 0.7785732746124268[s]
# principal_skinner_21.jpg
# []
# Elapsed time = 0.781975507736206[s]
# principal_skinner_22.jpg
# []
# Elapsed time = 0.7195019721984863[s]
# principal_skinner_23.jpg
# []
# Elapsed time = 0.7842607498168945[s]
# principal_skinner_24.jpg
# []
# Elapsed time = 0.7613167762756348[s]
# principal_skinner_25.jpg
# []
# Elapsed time = 0.8118383884429932[s]
# principal_skinner_26.jpg
# []
# Elapsed time = 0.7822751998901367[s]
# principal_skinner_27.jpg
# []
# Elapsed time = 0.8128206729888916[s]
# principal_skinner_28.jpg
# []
# Elapsed time = 0.8612940311431885[s]
# principal_skinner_29.jpg
# []
# Elapsed time = 0.8518593311309814[s]
# principal_skinner_3.jpg
# []
# Elapsed time = 0.7408604621887207[s]
# principal_skinner_30.jpg
# []
# Elapsed time = 0.8595535755157471[s]
# principal_skinner_31.jpg
# []
# Elapsed time = 0.8602485656738281[s]
# principal_skinner_32.jpg
# []
# Elapsed time = 0.8290324211120605[s]
# principal_skinner_33.jpg
# []
# Elapsed time = 0.8270976543426514[s]
# principal_skinner_34.jpg
# []
# Elapsed time = 0.8279597759246826[s]
# principal_skinner_35.jpg
# []
# Elapsed time = 0.7849252223968506[s]
# principal_skinner_36.jpg
# [('marge_simpson', 70.23857831954956), ('chief_wiggum', 55.45662045478821)]
# Elapsed time = 0.8189883232116699[s]
# principal_skinner_37.jpg
# []
# Elapsed time = 0.7870621681213379[s]
# principal_skinner_38.jpg
# []
# Elapsed time = 0.8441257476806641[s]
# principal_skinner_39.jpg
# []
# Elapsed time = 0.8250234127044678[s]
# principal_skinner_4.jpg
# []
# Elapsed time = 0.8166887760162354[s]
# principal_skinner_40.jpg
# []
# Elapsed time = 0.7640666961669922[s]
# principal_skinner_41.jpg
# []
# Elapsed time = 0.80426025390625[s]
# principal_skinner_42.jpg
# []
# Elapsed time = 0.8207376003265381[s]
# principal_skinner_43.jpg
# []
# Elapsed time = 0.789924144744873[s]
# principal_skinner_44.jpg
# []
# Elapsed time = 0.8625705242156982[s]
# principal_skinner_45.jpg
# []
# Elapsed time = 0.8022220134735107[s]
# principal_skinner_46.jpg
# []
# Elapsed time = 0.7955963611602783[s]
# principal_skinner_47.jpg
# []
# Elapsed time = 1.186861515045166[s]
# principal_skinner_48.jpg
# [('marge_simpson', 60.91843247413635)]
# Elapsed time = 0.7741060256958008[s]
# principal_skinner_49.jpg
# []
# Elapsed time = 0.74153733253479[s]
# principal_skinner_5.jpg
# []
# Elapsed time = 0.776132345199585[s]
# principal_skinner_6.jpg
# [('marge_simpson', 56.56172037124634)]
# Elapsed time = 0.7852845191955566[s]
# principal_skinner_7.jpg
# [('marge_simpson', 60.90850234031677)]
# Elapsed time = 0.8071837425231934[s]
# principal_skinner_8.jpg
# []
# Elapsed time = 0.8111591339111328[s]
# principal_skinner_9.jpg
# []
# Elapsed time = 0.8207173347473145[s]
# sideshow_bob_0.jpg
# []
# Elapsed time = 0.8409302234649658[s]
# sideshow_bob_1.jpg
# []
# Elapsed time = 0.7837295532226562[s]
# sideshow_bob_10.jpg
# []
# Elapsed time = 0.8281800746917725[s]
# sideshow_bob_11.jpg
# []
# Elapsed time = 0.8127307891845703[s]
# sideshow_bob_12.jpg
# []
# Elapsed time = 0.8093643188476562[s]
# sideshow_bob_13.jpg
# []
# Elapsed time = 0.8280997276306152[s]
# sideshow_bob_14.jpg
# []
# Elapsed time = 0.7815091609954834[s]
# sideshow_bob_15.jpg
# []
# Elapsed time = 0.782397985458374[s]
# sideshow_bob_16.jpg
# []
# Elapsed time = 0.8298072814941406[s]
# sideshow_bob_17.jpg
# []
# Elapsed time = 0.7798309326171875[s]
# sideshow_bob_18.jpg
# []
# Elapsed time = 0.8110880851745605[s]
# sideshow_bob_19.jpg
# []
# Elapsed time = 0.7862675189971924[s]
# sideshow_bob_2.jpg
# []
# Elapsed time = 0.8741791248321533[s]
# sideshow_bob_20.jpg
# []
# Elapsed time = 0.8912880420684814[s]
# sideshow_bob_21.jpg
# []
# Elapsed time = 0.7817761898040771[s]
# sideshow_bob_22.jpg
# [('marge_simpson', 86.53645515441895)]
# Elapsed time = 0.7851002216339111[s]
# sideshow_bob_23.jpg
# []
# Elapsed time = 0.803215742111206[s]
# sideshow_bob_24.jpg
# []
# Elapsed time = 0.783043384552002[s]
# sideshow_bob_25.jpg
# []
# Elapsed time = 0.8917026519775391[s]
# sideshow_bob_26.jpg
# []
# Elapsed time = 0.7818603515625[s]
# sideshow_bob_27.jpg
# []
# Elapsed time = 0.7896811962127686[s]
# sideshow_bob_28.jpg
# []
# Elapsed time = 0.8422236442565918[s]
# sideshow_bob_29.jpg
# []
# Elapsed time = 0.8373675346374512[s]
# sideshow_bob_3.jpg
# []
# Elapsed time = 0.8760409355163574[s]
# sideshow_bob_30.jpg
# []
# Elapsed time = 0.7819581031799316[s]
# sideshow_bob_31.jpg
# []
# Elapsed time = 0.8286283016204834[s]
# sideshow_bob_32.jpg
# []
# Elapsed time = 0.8150420188903809[s]
# sideshow_bob_33.jpg
# []
# Elapsed time = 0.7826695442199707[s]
# sideshow_bob_34.jpg
# []
# Elapsed time = 0.7941229343414307[s]
# sideshow_bob_36.jpg
# []
# Elapsed time = 0.8285131454467773[s]
# sideshow_bob_37.jpg
# []
# Elapsed time = 0.7662079334259033[s]
# sideshow_bob_38.jpg
# []
# Elapsed time = 0.7834107875823975[s]
# sideshow_bob_39.jpg
# []
# Elapsed time = 0.7942397594451904[s]
# sideshow_bob_4.jpg
# []
# Elapsed time = 0.795020580291748[s]
# sideshow_bob_40.jpg
# []
# Elapsed time = 0.7978549003601074[s]
# sideshow_bob_41.jpg
# []
# Elapsed time = 0.7975454330444336[s]
# sideshow_bob_42.jpg
# []
# Elapsed time = 0.8122727870941162[s]
# sideshow_bob_43.jpg
# []
# Elapsed time = 0.7806999683380127[s]
# sideshow_bob_44.jpg
# []
# Elapsed time = 0.8592641353607178[s]
# sideshow_bob_45.jpg
# []
# Elapsed time = 0.8125853538513184[s]
# sideshow_bob_47.jpg
# []
# Elapsed time = 0.7816643714904785[s]
# sideshow_bob_48.jpg
# []
# Elapsed time = 0.8265066146850586[s]
# sideshow_bob_49.jpg
# [('marge_simpson', 60.3626012802124)]
# Elapsed time = 0.7863378524780273[s]
# sideshow_bob_5.jpg
# []
# Elapsed time = 0.8147740364074707[s]
# sideshow_bob_7.jpg
# []
# Elapsed time = 0.8467772006988525[s]
# sideshow_bob_8.jpg
# []
# Elapsed time = 0.822096586227417[s]
# sideshow_bob_9.jpg
# []
# Elapsed time = 0.837186336517334[s]

# %% [markdown]
# <img src="result_chief_wiggum_33.jpg.png">

# %% [markdown]
# 学習回数を減らしたためなぜかChief以外上手くいってなかった

# %% [markdown]
# ### 【問題2】論文と実装の対応

# %% [markdown]
# Faster R-CNN[1]において重要だと考えた部分を列挙

# %% [markdown]
# RPNを実現しているコード
#
# Anchor
#
# class分類
#
# RoIプーリングを実現しているコード

# %% [markdown]
# ### RPNを実現しているコード

# %%
C = config()
img_input = Input(shape=(None, None, 3))
roi_input = Input(shape=(C.num_rois, 4))
# define the base network (resnet here)
shared_layers = nn.nn_base(img_input, trainable=True)

# define the RPN, built on the base layers
# anchorの数はbox_scalesとアスペクト比の組み合わせ
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
# kerasのrpn
rpn = nn.rpn(shared_layers, num_anchors)

# %% [markdown]
# ###  class分類を実現するコード

# %%
C = config()
img_input = Input(shape=(None, None, 3))
roi_input = Input(shape=(C.num_rois, 4))
# define the base network (resnet here)
shared_layers = nn.nn_base(img_input, trainable=True)

# define the classifer, built on the base layers
classifier = nn.classifier(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count), trainable=True)

# %% [markdown]
# ### Anchor

# %%
self.anchor_box_scales = [64, 128, 256, 512]
self.anchor_box_ratios = [[1, 1], [1, 2], [2, 1]]

# %% [markdown]
# ### RoIプーリングを実現しているコード

# %%
from keras.engine.topology import Layer
import keras.backend as K

if K.backend() == 'tensorflow':
    import tensorflow as tf

class RoiPoolingConv(Layer):
    '''ROI pooling layer for 2D inputs.
    See Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition,
    K. He, X. Zhang, S. Ren, J. Sun
    # Arguments
        pool_size: int
            Size of pooling region to use. pool_size = 7 will result in a 7x7 region.
        num_rois: number of regions of interest to be used
    # Input shape
        list of two 4D tensors [X_img,X_roi] with shape:
        X_img:
        `(1, channels, rows, cols)` if dim_ordering='th'
        or 4D tensor with shape:
        `(1, rows, cols, channels)` if dim_ordering='tf'.
        X_roi:
        `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
    # Output shape
        3D tensor with shape:
        `(1, num_rois, channels, pool_size, pool_size)`
    '''
    def __init__(self, pool_size, num_rois, **kwargs):

        self.dim_ordering = K.image_dim_ordering()
        assert self.dim_ordering in {'tf', 'th'}, 'dim_ordering must be in {tf, th}'

        self.pool_size = pool_size
        self.num_rois = num_rois

        super(RoiPoolingConv, self).__init__(**kwargs)

    def build(self, input_shape):
        if self.dim_ordering == 'th':
            self.nb_channels = input_shape[0][1]
        elif self.dim_ordering == 'tf':
            self.nb_channels = input_shape[0][3]

    def compute_output_shape(self, input_shape):
        if self.dim_ordering == 'th':
            return None, self.num_rois, self.nb_channels, self.pool_size, self.pool_size
        else:
            return None, self.num_rois, self.pool_size, self.pool_size, self.nb_channels

    def call(self, x, mask=None):

        assert(len(x) == 2)

        img = x[0]
        rois = x[1]

        input_shape = K.shape(img)

        outputs = []

        for roi_idx in range(self.num_rois):

            x = rois[0, roi_idx, 0]
            y = rois[0, roi_idx, 1]
            w = rois[0, roi_idx, 2]
            h = rois[0, roi_idx, 3]
            
            row_length = w / float(self.pool_size)
            col_length = h / float(self.pool_size)

            num_pool_regions = self.pool_size

            #NOTE: the RoiPooling implementation differs between theano and tensorflow due to the lack of a resize op
            # in theano. The theano implementation is much less efficient and leads to long compile times

            if self.dim_ordering == 'th':
                for jy in range(num_pool_regions):
                    for ix in range(num_pool_regions):
                        x1 = x + ix * row_length
                        x2 = x1 + row_length
                        y1 = y + jy * col_length
                        y2 = y1 + col_length

                        x1 = K.cast(x1, 'int32')
                        x2 = K.cast(x2, 'int32')
                        y1 = K.cast(y1, 'int32')
                        y2 = K.cast(y2, 'int32')

                        x2 = x1 + K.maximum(1,x2-x1)
                        y2 = y1 + K.maximum(1,y2-y1)
                        
                        new_shape = [input_shape[0], input_shape[1],
                                     y2 - y1, x2 - x1]

                        x_crop = img[:, :, y1:y2, x1:x2]
                        xm = K.reshape(x_crop, new_shape)
                        pooled_val = K.max(xm, axis=(2, 3))
                        outputs.append(pooled_val)

            elif self.dim_ordering == 'tf':
                x = K.cast(x, 'int32')
                y = K.cast(y, 'int32')
                w = K.cast(w, 'int32')
                h = K.cast(h, 'int32')

                rs = tf.image.resize_images(img[:, y:y+h, x:x+w, :], (self.pool_size, self.pool_size))
                outputs.append(rs)

        final_output = K.concatenate(outputs, axis=0)
        final_output = K.reshape(final_output, (1, self.num_rois, self.pool_size, self.pool_size, self.nb_channels))

        if self.dim_ordering == 'th':
            final_output = K.permute_dimensions(final_output, (0, 1, 4, 2, 3))
        else:
            final_output = K.permute_dimensions(final_output, (0, 1, 2, 3, 4))

        return final_output
