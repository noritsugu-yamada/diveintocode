# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/pdollar/coco.git
# Out:
# fatal: destination path 'coco' already exists and is not an empty directory.

# %%
cd coco/PythonAPI/
# Out:
# /content/coco/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# skipping 'pycocotools/_mask.c' Cython extension (up-to-date)
# copying build/lib.linux-x86_64-3.6/pycocotools/_mask.cpython-36m-x86_64-linux-gnu.so -> pycocotools
# rm -rf build

# %%
# !python setup.py build

# %%
# !python setup.py install

# %%
cd ../../
# Out:
# /content

# %%
# !git clone https://github.com/yunjey/pytorch-tutorial.git
# Out:
# fatal: destination path 'pytorch-tutorial' already exists and is not an empty directory.

# %%
cd pytorch-tutorial/tutorials/03-advanced/image_captioning/
# Out:
# /content/pytorch-tutorial/tutorials/03-advanced/image_captioning

# %%
# 重みとモデルのダウンロード
# !wget https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# Out:
# --2019-03-30 06:12:45--  https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# Resolving files.pythonhosted.org (files.pythonhosted.org)... 151.101.1.63, 151.101.65.63, 151.101.129.63, ...
# Connecting to files.pythonhosted.org (files.pythonhosted.org)|151.101.1.63|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23000 (22K) [application/octet-stream]
# Saving to: ‘argparse-1.4.0-py2.py3-none-any.whl.2’
#
# argparse-1.4.0-py2. 100%[===================>]  22.46K  --.-KB/s    in 0.01s
#
# 2019-03-30 06:12:45 (2.25 MB/s) - ‘argparse-1.4.0-py2.py3-none-any.whl.2’ saved [23000/23000]

# %%
# !wget https://www.dropbox.com/s/ne0ixz5d58ccbbz/pretrained_model.zip?dl=0
# Out:
# --2019-03-30 06:14:58--  https://www.dropbox.com/s/ne0ixz5d58ccbbz/pretrained_model.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ne0ixz5d58ccbbz/pretrained_model.zip [following]
# --2019-03-30 06:14:58--  https://www.dropbox.com/s/raw/ne0ixz5d58ccbbz/pretrained_model.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc2cfee5d3a64861833409a47d79.dl.dropboxusercontent.com/cd/0/inline/AeCmxHbVpehCoPjuYF2-e3EQGl0HKh7WDKOEJSRoEz811dXHHBIMqN7zTenxNZkaipPQh2dRN-2benX_6lVHu5LqgO2spRd11mCZzWTxUXqWp4RsPHFTqfta_bOAVevSpxE/file# [following]
# ...

# %%
# !wget https://www.dropbox.com/s/26adb7y9m98uisa/vocap.zip?dl=0
# Out:
# --2019-03-30 06:15:22--  https://www.dropbox.com/s/26adb7y9m98uisa/vocap.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/26adb7y9m98uisa/vocap.zip [following]
# --2019-03-30 06:15:22--  https://www.dropbox.com/s/raw/26adb7y9m98uisa/vocap.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd2b8b5abea94afaf0db1f2f128.dl.dropboxusercontent.com/cd/0/inline/AeCsyzSC_PB6q2-S69NKadyVzgCzrBPvkzeA2CkFovZaFReTsBcIxyZbrrk7EyqT6TgfXlpfNKw_35tJWPFSSjt0AWpGlFATrvDbHOXdUxyWl4P6vXay5jx-72biFCeED08/file# [following]
# ...

# %%
# !unzip vocap.zip?dl=0
# Out:
# Archive:  vocap.zip?dl=0
# replace vocab.pkl? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: vocab.pkl

# %%
# !unzip pretrained_model.zip?dl=0
# Out:
# Archive:  pretrained_model.zip?dl=0
# replace encoder-5-3000.pkl? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: encoder-5-3000.pkl
#
# replace decoder-5-3000.pkl? [y]es, [n]o, [A]ll, [N]one, [r]ename: error:  invalid response [{ENTER}]
# replace decoder-5-3000.pkl? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: decoder-5-3000.pkl

# %%
# !mkdir data
# !mkdir models

# %%
# !mv vocab.pkl data

# %%
# 名前の変更
# !mv encoder-5-3000.pkl encoder-2-1000.ckpt

# %%
# !mv encoder-2-1000.ckpt models

# %%
# !mv decoder-5-3000.pkl decoder-2-1000.ckpt

# %%
# !mv decoder-2-1000.ckpt models
# Out:
# mv: cannot stat 'decoder-2-1000.ckpt': No such file or directory

# %%
# sample imageの描出
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

im = Image.open("./png/example.png")
plt.imshow(np.array(im))

# %%
# !python sample.py --image='png/example.png'
# Out:
# <start> a group of giraffes standing next to each other . <end>

# %%
# !wget https://blog-001.west.edge.storage-yahoo.jp/res/blog-7f-53/rokumonkai/folder/350214/56/3603756/img_0?1305561678
# Out:
# --2019-03-30 07:14:14--  https://blog-001.west.edge.storage-yahoo.jp/res/blog-7f-53/rokumonkai/folder/350214/56/3603756/img_0?1305561678
# Resolving blog-001.west.edge.storage-yahoo.jp (blog-001.west.edge.storage-yahoo.jp)... 183.79.250.251
# Connecting to blog-001.west.edge.storage-yahoo.jp (blog-001.west.edge.storage-yahoo.jp)|183.79.250.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60246 (59K) [image/jpeg]
# Saving to: ‘img_0?1305561678’
#
# img_0?1305561678    100%[===================>]  58.83K   148KB/s    in 0.4s
#
# 2019-03-30 07:14:15 (148 KB/s) - ‘img_0?1305561678’ saved [60246/60246]

# %%
# !mv img_0?1305561678

# %%
# sample imageの描出
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

im = Image.open("img_0?1305561678")
plt.imshow(np.array(im))

# %%
# !python sample.py --image='img_0?1305561678'
# Out:
# <start> a white and white bird sitting on a table . <end>

# %%
# !pip install mmdnn
# Out:
# ...
#     100% |████████████████████████████████| 317kB 23.3MB/s
# ...
#     100% |████████████████████████████████| 17.3MB 2.2MB/s
# ...
# featuretools 0.4.1 has requirement pandas>=0.23.0, but you'll have pandas 0.22.0 which is incompatible.
# datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.8 which is incompatible.
# ...
#   Found existing installation: numpy 1.14.6
#     Uninstalling numpy-1.14.6:
#       Successfully uninstalled numpy-1.14.6
# ...
